# %%
import torch.nn as nn
import torch
import torch.utils.data as data
import numpy as np
from tqdm import tqdm
import torch.optim as optim
import os
import scipy.io as sio
from collections import defaultdict, deque
import datetime
import time
import torch.distributed as dist
import errno
import torch.nn.functional as F
import math
import random
from matplotlib import pyplot as plt
from torchvision import transforms

# %%
class SmoothedValue(object):
    """Track a series of values and provide access to smoothed values over a
    window or the global series average.
    """

    def __init__(self, window_size=20, fmt=None):
        if fmt is None:
            fmt = "{value:.4f} ({global_avg:.4f})"
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    def synchronize_between_processes(self):
        """
        Warning: does not synchronize the deque!
        """
        if not is_dist_avail_and_initialized():
            return
        t = torch.tensor([self.count, self.total], dtype=torch.float64, device='cuda')
        dist.barrier()
        dist.all_reduce(t)
        t = t.tolist()
        self.count = int(t[0])
        self.total = t[1]

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count

    @property
    def max(self):
        return max(self.deque)

    @property
    def value(self):
        return self.deque[-1]

    def __str__(self):
        return self.fmt.format(
            median=self.median,
            avg=self.avg,
            global_avg=self.global_avg,
            max=self.max,
            value=self.value)

class MetricLogger(object):
    def __init__(self, delimiter="\t"):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            assert isinstance(v, (float, int))
            self.meters[k].update(v)

    def __getattr__(self, attr):
        if attr in self.meters:
            return self.meters[attr]
        if attr in self.__dict__:
            return self.__dict__[attr]
        raise AttributeError("'{}' object has no attribute '{}'".format(
            type(self).__name__, attr))

    def __str__(self):
        loss_str = []
        for name, meter in self.meters.items():
            loss_str.append(
                "{}: {}".format(name, str(meter))
            )
        return self.delimiter.join(loss_str)

    def synchronize_between_processes(self):
        for meter in self.meters.values():
            meter.synchronize_between_processes()

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        if not header:
            header = ''
        start_time = time.time()
        end = time.time()
        iter_time = SmoothedValue(fmt='{avg:.4f}')
        data_time = SmoothedValue(fmt='{avg:.4f}')
        space_fmt = ':' + str(len(str(len(iterable)))) + 'd'
        if torch.cuda.is_available():
            log_msg = self.delimiter.join([
                header,
                '[{0' + space_fmt + '}/{1}]',
                'eta: {eta}',
                '{meters}',
                'time: {time}',
                'data: {data}',
                'max mem: {memory:.0f}'
            ])
        else:
            log_msg = self.delimiter.join([
                header,
                '[{0' + space_fmt + '}/{1}]',
                'eta: {eta}',
                '{meters}',
                'time: {time}',
                'data: {data}'
            ])
        MB = 1024.0 * 1024.0
        for obj in iterable:
            data_time.update(time.time() - end)
            yield obj
            iter_time.update(time.time() - end)
            if i % print_freq == 0:
                eta_seconds = iter_time.global_avg * (len(iterable) - i)
                eta_string = str(datetime.timedelta(seconds=int(eta_seconds)))
                if torch.cuda.is_available():
                    print(log_msg.format(
                        i, len(iterable), eta=eta_string,
                        meters=str(self),
                        time=str(iter_time), data=str(data_time),
                        memory=torch.cuda.max_memory_allocated() / MB))
                else:
                    print(log_msg.format(
                        i, len(iterable), eta=eta_string,
                        meters=str(self),
                        time=str(iter_time), data=str(data_time)))
            i += 1
            end = time.time()
        total_time = time.time() - start_time
        total_time_str = str(datetime.timedelta(seconds=int(total_time)))
        print('{} Total time: {}'.format(header, total_time_str))


def mkdir(path):
    try:
        os.makedirs(path)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise

def is_dist_avail_and_initialized():
    if not dist.is_available():
        return False
    if not dist.is_initialized():
        return False
    return True

# %%
# transform
def transform_data():
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])
    return transform

# create dataset class
class channel_dataset(data.Dataset):
    def __init__(self, data_path, use_noise: bool = False, is_train: bool = True):
        super(channel_dataset, self).__init__()
        self.data_path = data_path
        self.data = sio.loadmat(data_path)
        self.use_noise = use_noise
        self.is_train = is_train

        self.trans = transform_data()

        self.tx_data = self.data['Xt_train'] if self.is_train else self.data['Xt_val']
        self.rx_data = self.data['rx_Xt_train'] if self.is_train else self.data['rx_Xt_val']
        self.rx_data_noised = self.data['rx_Xt_noise_train'] if self.is_train else self.data['rx_Xt_noise_val']

        self.tx_data = self.tx_data.astype(np.float32)
        self.rx_data = self.rx_data.astype(np.float32)
        self.rx_data_noised = self.rx_data_noised.astype(np.float32)

        # use min-max normalize to rescale the data to int val of [10, 240]
        self.tx_data = (self.tx_data - np.min(self.tx_data)) / (np.max(self.tx_data) - np.min(self.tx_data)) * 230 + 10
        self.rx_data = (self.rx_data - np.min(self.rx_data)) / (np.max(self.rx_data) - np.min(self.rx_data)) * 230 + 10
        self.rx_data_noised = (self.rx_data_noised - np.min(self.rx_data_noised)) / (np.max(self.rx_data_noised) - np.min(self.rx_data_noised)) * 230 + 10

        self.tx_data = self.tx_data.astype(np.uint8)
        self.rx_data = self.rx_data.astype(np.uint8)
        self.rx_data_noised = self.rx_data_noised.astype(np.uint8)

        # transfer the tx_data's each element into 7-bits binary digits, as the range is in [0, 128]
        self.tx_data_label = np.unpackbits(self.tx_data, axis=-1)
        self.tx_data_label = self.tx_data_label.reshape(*self.tx_data.shape, -1)
        self.tx_data_label = self.tx_data_label[:, :, 0:].reshape(-1, 64 * 8).astype(float)

        self.tx_pilot, self.tx_data = self.tx_data[:64], self.tx_data[64:].reshape(-1, 8, 8, 1)
        self.rx_pilot, self.rx_data = self.rx_data[:64], self.rx_data[64:].reshape(-1, 8, 8, 1)
        self.rx_pilot_noised, self.rx_data_noised = self.rx_data_noised[:64], self.rx_data_noised[64:].reshape(-1, 8, 8, 1)
        self.tx_data_label_pilot, self.tx_data_label = self.tx_data_label[:64], self.tx_data_label[64:]

        self.tx_pilot = self.tx_pilot[:, :, None]
        self.rx_pilot, self.rx_pilot_noised = self.rx_pilot[:, :, None], self.rx_pilot_noised[:, :, None]

        self.num_samples = self.tx_data.shape[0]

    def __len__(self):
        return self.num_samples

    def __get_pilot__(self):
        if self.use_noise:
            return self.trans(self.tx_pilot).unsqueeze(0), self.trans(self.rx_pilot_noised).unsqueeze(0)
        else:
            return self.trans(self.tx_pilot).unsqueeze(0), self.trans(self.rx_pilot).unsqueeze(0)

    def __getitem__(self, index):
        if self.use_noise:
            # return self.trans(self.tx_data[index]).view(-1), self.trans(self.rx_data_noised[index])
            return torch.tensor(self.tx_data_label[index]), self.trans(self.rx_data_noised[index])
        else:
            # return self.trans(self.tx_data[index]).view(-1), self.trans(self.rx_data[index])
            return torch.tensor(self.tx_data_label[index]), self.trans(self.rx_data[index])


class channel_dataset_after_CNN(data.Dataset):
    def __init__(self, data_path, use_noise: bool = False, is_train: bool = True):
        super(channel_dataset_after_CNN, self).__init__()
        self.data_path = data_path
        self.data = sio.loadmat(data_path)
        self.use_noise = use_noise
        self.is_train = is_train
        self.HW_data = np.load(data_path.replace("channel_equal_train.mat", "train_output.npy")) if self.is_train else np.load(data_path.replace("channel_equal_val.mat", "test_output.npy"))

        self.trans = transform_data()

        self.tx_data = self.data['Xt_train'] if self.is_train else self.data['Xt_val']
        self.rx_data = self.data['rx_Xt_train'] if self.is_train else self.data['rx_Xt_val']
        self.rx_data_noised = self.data['rx_Xt_noise_train'] if self.is_train else self.data['rx_Xt_noise_val']

        self.tx_data = self.tx_data.astype(np.float32)
        self.rx_data = self.rx_data.astype(np.float32)
        self.rx_data_noised = self.rx_data_noised.astype(np.float32)

        # use min-max normalize to rescale the data to int val of [10, 240]
        self.tx_data = (self.tx_data - np.min(self.tx_data)) / (np.max(self.tx_data) - np.min(self.tx_data)) * 230 + 10
        self.rx_data = (self.rx_data - np.min(self.rx_data)) / (np.max(self.rx_data) - np.min(self.rx_data)) * 230 + 10
        self.rx_data_noised = (self.rx_data_noised - np.min(self.rx_data_noised)) / (np.max(self.rx_data_noised) - np.min(self.rx_data_noised)) * 230 + 10
        self.HW_data = ((self.HW_data / 255 + 1) / 2 * 230 + 10).astype(np.uint8).reshape(-1, 8, 16, 1)
        
        self.tx_data = self.tx_data.astype(np.uint8)
        self.rx_data = self.rx_data.astype(np.uint8)
        self.rx_data_noised = self.rx_data_noised.astype(np.uint8)

        # transfer the tx_data's each element into 7-bits binary digits, as the range is in [0, 128]
        self.tx_data_label = np.unpackbits(self.tx_data, axis=-1)
        self.tx_data_label = self.tx_data_label.reshape(*self.tx_data.shape, -1)
        self.tx_data_label = self.tx_data_label[:, :, 0:].reshape(-1, 64 * 8).astype(float)

        self.tx_pilot, self.tx_data = self.tx_data[:64], self.tx_data[64:].reshape(-1, 8, 8, 1)
        self.rx_pilot, self.rx_data = self.rx_data[:64], self.rx_data[64:].reshape(-1, 8, 8, 1)
        self.rx_pilot_noised, self.rx_data_noised = self.rx_data_noised[:64], self.rx_data_noised[64:].reshape(-1, 8, 8, 1)
        self.tx_data_label_pilot, self.tx_data_label = self.tx_data_label[:64], self.tx_data_label[64:]

        self.tx_pilot = self.tx_pilot[:, :, None]
        self.rx_pilot, self.rx_pilot_noised = self.rx_pilot[:, :, None], self.rx_pilot_noised[:, :, None]

        self.num_samples = self.tx_data.shape[0]

    def __len__(self):
        return self.num_samples

    def __get_pilot__(self):
        if self.use_noise:
            return self.trans(self.tx_pilot).unsqueeze(0), self.trans(self.rx_pilot_noised).unsqueeze(0)
        else:
            return self.trans(self.tx_pilot).unsqueeze(0), self.trans(self.rx_pilot).unsqueeze(0)

    def __getitem__(self, index):
        if self.use_noise:
            # return self.trans(self.tx_data[index]).view(-1), self.trans(self.HW_data[index]).view(-1)
            return torch.tensor(self.tx_data_label[index]), self.trans(self.HW_data[index])
        else:
            # return self.trans(self.tx_data[index]).view(-1), self.trans(self.rx_data[index])
            return torch.tensor(self.tx_data_label[index]), self.trans(self.rx_data[index])

# %%
# equalizer model
class Equalizer(nn.Module):
    def __init__(self, input_size: int = 64, latent_size: int = 64):
        super(Equalizer, self).__init__()
        self.pilot_encoder = nn.Sequential(
            nn.Conv2d(2, 4, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(4, 8, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(8, 8, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(8, 16, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 16, 3, 1, 1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(2 * 2 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, latent_size)
        )

        self.equalizer = nn.Sequential(
            nn.Conv2d(1, 4, 3, 1, 1),
            nn.AvgPool2d(2),
            nn.Conv2d(4, 8, 3, 1, 1),
            nn.AvgPool2d(2),
            nn.Conv2d(8, 16, 3, 1, 1),
            nn.Flatten(),
            nn.Linear(2 * 4 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, input_size * 8)
        )

    def forward(self, tx_pilot, rx_pilot, rx_input):
        pilot_latent = self.pilot_encoder(torch.cat((tx_pilot, rx_pilot), dim=1)).view(-1, 1, 8, 8)
        equalized_output = torch.cat((pilot_latent, rx_input), dim=-1)
        equalized_output = self.equalizer(equalized_output)
        return equalized_output

class Equalizer_HW(nn.Module):
    def __init__(self, input_size: int = 64, latent_size: int = 64):
        super(Equalizer_HW, self).__init__()
        self.equalizer = nn.Sequential(
            nn.Conv2d(1, 4, 3, 1, 1),
            nn.AvgPool2d(2),
            nn.Conv2d(4, 8, 3, 1, 1),
            nn.AvgPool2d(2),
            nn.Conv2d(8, 16, 3, 1, 1),
            nn.Flatten(),
            nn.Linear(2 * 4 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, input_size * 8)
        )

    def forward(self, rx_input):
        equalized_output = rx_input
        equalized_output = self.equalizer(equalized_output)
        return equalized_output


class Equalizer_HW_after_CNN(nn.Module):
    def __init__(self, input_size: int = 64, latent_size: int = 64):
        super(Equalizer_HW_after_CNN, self).__init__()
        self.equalizer = nn.Sequential(
            nn.Flatten(),
            nn.Linear(2 * 4 * 16, 128),
            nn.ReLU(),
            # nn.Linear(128, 128),
            # nn.ReLU(),
            nn.Linear(128, input_size * 8),
        )

    def forward(self, rx_input):
        equalized_output = rx_input
        equalized_output = self.equalizer(equalized_output)
        return equalized_output

# %%
def quantize_regularize(model, device, alpha=0.2):
    central_params = torch.arange(0.0, 1.05, 0.05).to(device)
    reg_params = {}
    for c in central_params:
        if c == 0.0:
            reg_params[c] = [p.abs() < 0.025 for n, p in model.named_parameters()]
        if c == 1.0:
            reg_params[c] = [p.abs() > 0.975 for n, p in model.named_parameters()]
        else:
            reg_params[c] = [(c - 0.025 <= p.abs()) & (p.abs() < c + 0.025) for n, p in model.named_parameters()]

    reg_loss = 0.0
    for c, params in reg_params.items():
        reg_loss += alpha * torch.sum(torch.stack([torch.sum((p[params[i]].abs() - c).abs()) for i, (n, p) in enumerate(model.named_parameters())]))

    return reg_loss


# train one epoch
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq, scaler):
    model.train()
    metric_logger = MetricLogger(delimiter="    ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    # take pilots
    tx_pilot, rx_pilot = data_loader.dataset.__get_pilot__()
    tx_pilot, rx_pilot = tx_pilot.to(device), rx_pilot.to(device)

    # expand pilots among the batch_size dim
    tx_pilot = tx_pilot.expand(data_loader.batch_size, -1, -1, -1)
    rx_pilot = rx_pilot.expand(data_loader.batch_size, -1, -1, -1)

    for tx_input, rx_input in metric_logger.log_every(data_loader, print_freq, header):
        tx_input, rx_input = tx_input.to(device), rx_input.to(device)

        with torch.amp.autocast('cuda'):
            # equalized_output = model(tx_pilot, rx_pilot, rx_input)
            equalized_output = model(rx_input)
            loss = F.binary_cross_entropy_with_logits(equalized_output, tx_input)

            if epoch >= 10:
                loss += quantize_regularize(model, device)

            optimizer.zero_grad()
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

        metric_logger.update(loss=loss, lr=optimizer.param_groups[0]["lr"])
        # calculate binary accuracy
        output_bits = (equalized_output > 0).to(torch.uint8)
        accuracy = (output_bits == tx_input.to(torch.uint8)).float().mean()
        metric_logger.update(accuracy=accuracy)

    metric_logger.synchronize_between_processes()
    print("Averaged stats:", metric_logger)
    return {k: meter.global_avg for k, meter in metric_logger.meters.items()}

def evaluate(model, data_loader, device, epoch, print_freq):
    model.eval()
    metric_logger = MetricLogger(delimiter="    ")
    header = 'Test: Epoch: [{}]'.format(epoch)

    tx_pilot, rx_pilot = data_loader.dataset.__get_pilot__()
    tx_pilot, rx_pilot = tx_pilot.to(device), rx_pilot.to(device)

    tx_pilot = tx_pilot.expand(data_loader.batch_size, -1, -1, -1)
    rx_pilot = rx_pilot.expand(data_loader.batch_size, -1, -1, -1)
    tx_pilot.requires_grad = False
    rx_pilot.requires_grad = False

    with torch.no_grad():
        with torch.amp.autocast('cuda'):
            for tx_input, rx_input in metric_logger.log_every(data_loader, print_freq, header):
                tx_input, rx_input = tx_input.to(device), rx_input.to(device)

                # equalized_output = model(tx_pilot, rx_pilot, rx_input)
                equalized_output = model(rx_input)
                loss = F.binary_cross_entropy_with_logits(equalized_output, tx_input)

                metric_logger.update(loss=loss)
                # calculate binary accuracy
                output_bits = (equalized_output > 0).to(torch.uint8)
                accuracy = (output_bits == tx_input.to(torch.uint8)).float().mean()
                metric_logger.update(accuracy=accuracy)

    metric_logger.synchronize_between_processes()
    print("Averaged stats:", metric_logger)
    return {k: meter.global_avg for k, meter in metric_logger.meters.items()}

# %%
def main(snr):
    # set seed
    torch.manual_seed(42)
    np.random.seed(42)

    batch_size = 256
    num_epoch = 300
    lr = 0.01
    lrf = 0.1

    train_data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_train.mat"
    val_data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_val.mat"

    train_dataset = channel_dataset_after_CNN(train_data_path, use_noise=True, is_train=True)
    val_dataset = channel_dataset_after_CNN(val_data_path, use_noise=True, is_train=False)

    train_sampler = data.RandomSampler(train_dataset)
    val_sampler = data.SequentialSampler(val_dataset)

    train_loader = data.DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, drop_last=True)
    val_loader = data.DataLoader(val_dataset, batch_size=batch_size, sampler=val_sampler, drop_last=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # model = Equalizer().to(device)
    model = Equalizer_HW_after_CNN().to(device)

    params_to_optimize = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.Adam(params_to_optimize, lr=lr)
    scaler = torch.amp.GradScaler('cuda')

    lf = lambda x: ((1 + math.cos(x * math.pi / num_epoch)) / 2) * (1 - lrf) + lrf
    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lf)
    scheduler.last_epoch = 0

    best_loss, best_epoch = math.inf, 0
    start_time = time.time()
    for epoch in range(num_epoch):
        train_dict = train_one_epoch(model, optimizer, train_loader, device, epoch, print_freq=10, scaler=scaler)
        val_dict = evaluate(model, val_loader, device, epoch, print_freq=5)
        scheduler.step()

        if epoch >= 10 and val_dict['loss'] < best_loss:
            best_loss = val_dict['loss']
            best_epoch = epoch
            save_file = {
                "model": model.state_dict(),
                "optimizer": optimizer.state_dict(),
                "scheduler": scheduler.state_dict(),
                "epoch": epoch
            }
            torch.save(save_file, "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model.pth")
            print("Save model from: ", epoch)

    print("Total time: {}s".format(int(time.time() - start_time)))
    print("Best loss: {}".format(best_loss), ";  Best Epoch: {}".format(best_epoch))

    # min, max of the model parameters
    min_params, max_params = [], []
    for p in model.parameters():
        min_params.append(p.min().item())
        max_params.append(p.max().item())
    min_params, max_params = np.min(min_params), np.max(max_params)
    print(f"Min of model parameters: {min_params}, Max of model parameters: {max_params}")
    # plot histogram of model parameters
    params = [p.detach().cpu().numpy().flatten() for p in model.parameters()]
    plt.hist(np.hstack(params), bins=100)
    plt.show()

    return

# %%
snr = 20

# %%
main(snr)
# Out:
# Epoch: [0]    [ 0/31]    eta: 0:00:00    lr: 0.010000    loss: 0.6942 (0.6942)    accuracy: 0.5006 (0.5006)    time: 0.0184    data: 0.0163    max mem: 29
# Epoch: [0]    [10/31]    eta: 0:00:00    lr: 0.010000    loss: 0.5944 (0.6471)    accuracy: 0.6525 (0.6033)    time: 0.0280    data: 0.0260    max mem: 30
# Epoch: [0]    [20/31]    eta: 0:00:00    lr: 0.010000    loss: 0.5461 (0.6053)    accuracy: 0.6862 (0.6397)    time: 0.0232    data: 0.0214    max mem: 30
# Epoch: [0]    [30/31]    eta: 0:00:00    lr: 0.010000    loss: 0.5069 (0.5785)    accuracy: 0.7391 (0.6653)    time: 0.0177    data: 0.0159    max mem: 30
# Epoch: [0] Total time: 0:00:00
# Averaged stats: lr: 0.010000    loss: 0.5069 (0.5785)    accuracy: 0.7391 (0.6653)
# Test: Epoch: [0]    [0/7]    eta: 0:00:00    loss: 0.5085 (0.5085)    accuracy: 0.7366 (0.7366)    time: 0.0165    data: 0.0160    max mem: 30
# Test: Epoch: [0]    [5/7]    eta: 0:00:00    loss: 0.5004 (0.5035)    accuracy: 0.7457 (0.7424)    time: 0.0163    data: 0.0159    max mem: 30
# Test: Epoch: [0] Total time: 0:00:00
# Averaged stats: loss: 0.5050 (0.5037)    accuracy: 0.7423 (0.7424)
# Epoch: [1]    [ 0/31]    eta: 0:00:00    lr: 0.010000    loss: 0.4990 (0.4990)    accuracy: 0.7464 (0.7464)    time: 0.0188    data: 0.0169    max mem: 30
# Epoch: [1]    [10/31]    eta: 0:00:00    lr: 0.010000    loss: 0.4688 (0.4861)    accuracy: 0.7537 (0.7511)    time: 0.0178    data: 0.0160    max mem: 30
# Epoch: [1]    [20/31]    eta: 0:00:00    lr: 0.010000    loss: 0.4537 (0.4734)    accuracy: 0.7579 (0.7535)    time: 0.0177    data: 0.0159    max mem: 30
# Epoch: [1]    [30/31]    eta: 0:00:00    lr: 0.010000    loss: 0.4386 (0.4650)    accuracy: 0.7635 (0.7550)    time: 0.0181    data: 0.0163    max mem: 30
# Epoch: [1] Total time: 0:00:00
# Averaged stats: lr: 0.010000    loss: 0.4386 (0.4650)    accuracy: 0.7635 (0.7550)
# Test: Epoch: [1]    [0/7]    eta: 0:00:00    loss: 0.4475 (0.4475)    accuracy: 0.7634 (0.7634)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [1]    [5/7]    eta: 0:00:00    loss: 0.4387 (0.4413)    accuracy: 0.7659 (0.7648)    time: 0.0155    data: 0.0150    max mem: 30
# Test: Epoch: [1] Total time: 0:00:00
# Averaged stats: loss: 0.4423 (0.4415)    accuracy: 0.7644 (0.7647)
# Epoch: [2]    [ 0/31]    eta: 0:00:00    lr: 0.009999    loss: 0.4369 (0.4369)    accuracy: 0.7675 (0.7675)    time: 0.0180    data: 0.0161    max mem: 30
# Epoch: [2]    [10/31]    eta: 0:00:00    lr: 0.009999    loss: 0.4246 (0.4317)    accuracy: 0.7698 (0.7670)    time: 0.0177    data: 0.0158    max mem: 30
# Epoch: [2]    [20/31]    eta: 0:00:00    lr: 0.009999    loss: 0.4135 (0.4251)    accuracy: 0.7749 (0.7693)    time: 0.0176    data: 0.0158    max mem: 30
# Epoch: [2]    [30/31]    eta: 0:00:00    lr: 0.009999    loss: 0.3906 (0.4169)    accuracy: 0.7902 (0.7730)    time: 0.0179    data: 0.0161    max mem: 30
# Epoch: [2] Total time: 0:00:00
# Averaged stats: lr: 0.009999    loss: 0.3906 (0.4169)    accuracy: 0.7902 (0.7730)
# Test: Epoch: [2]    [0/7]    eta: 0:00:00    loss: 0.4101 (0.4101)    accuracy: 0.7796 (0.7796)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [2]    [5/7]    eta: 0:00:00    loss: 0.3915 (0.3968)    accuracy: 0.7916 (0.7876)    time: 0.0155    data: 0.0150    max mem: 30
# Test: Epoch: [2] Total time: 0:00:00
# Averaged stats: loss: 0.4004 (0.3973)    accuracy: 0.7837 (0.7871)
# Epoch: [3]    [ 0/31]    eta: 0:00:00    lr: 0.009998    loss: 0.3918 (0.3918)    accuracy: 0.7934 (0.7934)    time: 0.0179    data: 0.0160    max mem: 30
# Epoch: [3]    [10/31]    eta: 0:00:00    lr: 0.009998    loss: 0.3710 (0.3821)    accuracy: 0.7937 (0.7928)    time: 0.0177    data: 0.0159    max mem: 30
# Epoch: [3]    [20/31]    eta: 0:00:00    lr: 0.009998    loss: 0.3568 (0.3716)    accuracy: 0.8059 (0.7975)    time: 0.0176    data: 0.0158    max mem: 30
# Epoch: [3]    [30/31]    eta: 0:00:00    lr: 0.009998    loss: 0.3324 (0.3611)    accuracy: 0.8327 (0.8068)    time: 0.0176    data: 0.0158    max mem: 30
# Epoch: [3] Total time: 0:00:00
# Averaged stats: lr: 0.009998    loss: 0.3324 (0.3611)    accuracy: 0.8327 (0.8068)
# Test: Epoch: [3]    [0/7]    eta: 0:00:00    loss: 0.3519 (0.3519)    accuracy: 0.8087 (0.8087)    time: 0.0159    data: 0.0154    max mem: 30
# Test: Epoch: [3]    [5/7]    eta: 0:00:00    loss: 0.3337 (0.3376)    accuracy: 0.8256 (0.8220)    time: 0.0159    data: 0.0154    max mem: 30
# Test: Epoch: [3] Total time: 0:00:00
# Averaged stats: loss: 0.3392 (0.3378)    accuracy: 0.8193 (0.8216)
# Epoch: [4]    [ 0/31]    eta: 0:00:00    lr: 0.009996    loss: 0.3255 (0.3255)    accuracy: 0.8357 (0.8357)    time: 0.0187    data: 0.0169    max mem: 30
# Epoch: [4]    [10/31]    eta: 0:00:00    lr: 0.009996    loss: 0.3108 (0.3192)    accuracy: 0.8557 (0.8456)    time: 0.0179    data: 0.0162    max mem: 30
# Epoch: [4]    [20/31]    eta: 0:00:00    lr: 0.009996    loss: 0.2814 (0.3100)    accuracy: 0.8841 (0.8535)    time: 0.0180    data: 0.0162    max mem: 30
# Epoch: [4]    [30/31]    eta: 0:00:00    lr: 0.009996    loss: 0.2851 (0.3020)    accuracy: 0.8795 (0.8620)    time: 0.0184    data: 0.0165    max mem: 30
# Epoch: [4] Total time: 0:00:00
# Averaged stats: lr: 0.009996    loss: 0.2851 (0.3020)    accuracy: 0.8795 (0.8620)
# Test: Epoch: [4]    [0/7]    eta: 0:00:00    loss: 0.3063 (0.3063)    accuracy: 0.8560 (0.8560)    time: 0.0158    data: 0.0153    max mem: 30
# Test: Epoch: [4]    [5/7]    eta: 0:00:00    loss: 0.2882 (0.2902)    accuracy: 0.8722 (0.8707)    time: 0.0156    data: 0.0151    max mem: 30
# Test: Epoch: [4] Total time: 0:00:00
# Averaged stats: loss: 0.2934 (0.2906)    accuracy: 0.8646 (0.8698)
# Epoch: [5]    [ 0/31]    eta: 0:00:00    lr: 0.009994    loss: 0.2788 (0.2788)    accuracy: 0.8846 (0.8846)    time: 0.0179    data: 0.0161    max mem: 30
# Epoch: [5]    [10/31]    eta: 0:00:00    lr: 0.009994    loss: 0.2602 (0.2680)    accuracy: 0.8945 (0.8930)    time: 0.0196    data: 0.0175    max mem: 30
# Epoch: [5]    [20/31]    eta: 0:00:00    lr: 0.009994    loss: 0.2408 (0.2610)    accuracy: 0.9139 (0.8979)    time: 0.0193    data: 0.0172    max mem: 30
# Epoch: [5]    [30/31]    eta: 0:00:00    lr: 0.009994    loss: 0.2358 (0.2545)    accuracy: 0.9138 (0.9013)    time: 0.0196    data: 0.0176    max mem: 30
# Epoch: [5] Total time: 0:00:00
# Averaged stats: lr: 0.009994    loss: 0.2358 (0.2545)    accuracy: 0.9138 (0.9013)
# Test: Epoch: [5]    [0/7]    eta: 0:00:00    loss: 0.2671 (0.2671)    accuracy: 0.8887 (0.8887)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [5]    [5/7]    eta: 0:00:00    loss: 0.2447 (0.2479)    accuracy: 0.9045 (0.9043)    time: 0.0155    data: 0.0150    max mem: 30
# Test: Epoch: [5] Total time: 0:00:00
# Averaged stats: loss: 0.2479 (0.2479)    accuracy: 0.9022 (0.9040)
# Epoch: [6]    [ 0/31]    eta: 0:00:00    lr: 0.009991    loss: 0.2299 (0.2299)    accuracy: 0.9193 (0.9193)    time: 0.0181    data: 0.0161    max mem: 30
# Epoch: [6]    [10/31]    eta: 0:00:00    lr: 0.009991    loss: 0.2126 (0.2265)    accuracy: 0.9290 (0.9192)    time: 0.0187    data: 0.0167    max mem: 30
# Epoch: [6]    [20/31]    eta: 0:00:00    lr: 0.009991    loss: 0.2125 (0.2213)    accuracy: 0.9306 (0.9220)    time: 0.0185    data: 0.0166    max mem: 30
# Epoch: [6]    [30/31]    eta: 0:00:00    lr: 0.009991    loss: 0.2020 (0.2159)    accuracy: 0.9306 (0.9252)    time: 0.0183    data: 0.0164    max mem: 30
# Epoch: [6] Total time: 0:00:00
# Averaged stats: lr: 0.009991    loss: 0.2020 (0.2159)    accuracy: 0.9306 (0.9252)
# Test: Epoch: [6]    [0/7]    eta: 0:00:00    loss: 0.2329 (0.2329)    accuracy: 0.9145 (0.9145)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [6]    [5/7]    eta: 0:00:00    loss: 0.2108 (0.2131)    accuracy: 0.9262 (0.9268)    time: 0.0155    data: 0.0150    max mem: 30
# Test: Epoch: [6] Total time: 0:00:00
# Averaged stats: loss: 0.2097 (0.2126)    accuracy: 0.9298 (0.9272)
# Epoch: [7]    [ 0/31]    eta: 0:00:00    lr: 0.009988    loss: 0.2047 (0.2047)    accuracy: 0.9318 (0.9318)    time: 0.0181    data: 0.0161    max mem: 30
# Epoch: [7]    [10/31]    eta: 0:00:00    lr: 0.009988    loss: 0.1838 (0.1919)    accuracy: 0.9415 (0.9395)    time: 0.0178    data: 0.0159    max mem: 30
# Epoch: [7]    [20/31]    eta: 0:00:00    lr: 0.009988    loss: 0.1831 (0.1885)    accuracy: 0.9388 (0.9405)    time: 0.0177    data: 0.0159    max mem: 30
# Epoch: [7]    [30/31]    eta: 0:00:00    lr: 0.009988    loss: 0.1735 (0.1849)    accuracy: 0.9543 (0.9430)    time: 0.0181    data: 0.0162    max mem: 30
# Epoch: [7] Total time: 0:00:00
# Averaged stats: lr: 0.009988    loss: 0.1735 (0.1849)    accuracy: 0.9543 (0.9430)
# Test: Epoch: [7]    [0/7]    eta: 0:00:00    loss: 0.2114 (0.2114)    accuracy: 0.9270 (0.9270)    time: 0.0164    data: 0.0159    max mem: 30
# Test: Epoch: [7]    [5/7]    eta: 0:00:00    loss: 0.1883 (0.1905)    accuracy: 0.9411 (0.9411)    time: 0.0165    data: 0.0160    max mem: 30
# Test: Epoch: [7] Total time: 0:00:00
# Averaged stats: loss: 0.1874 (0.1901)    accuracy: 0.9441 (0.9416)
# Epoch: [8]    [ 0/31]    eta: 0:00:00    lr: 0.009984    loss: 0.1673 (0.1673)    accuracy: 0.9570 (0.9570)    time: 0.0191    data: 0.0170    max mem: 30
# Epoch: [8]    [10/31]    eta: 0:00:00    lr: 0.009984    loss: 0.1651 (0.1659)    accuracy: 0.9554 (0.9545)    time: 0.0182    data: 0.0163    max mem: 30
# Epoch: [8]    [20/31]    eta: 0:00:00    lr: 0.009984    loss: 0.1516 (0.1638)    accuracy: 0.9549 (0.9545)    time: 0.0182    data: 0.0164    max mem: 30
# Epoch: [8]    [30/31]    eta: 0:00:00    lr: 0.009984    loss: 0.1448 (0.1592)    accuracy: 0.9668 (0.9572)    time: 0.0186    data: 0.0166    max mem: 30
# Epoch: [8] Total time: 0:00:00
# Averaged stats: lr: 0.009984    loss: 0.1448 (0.1592)    accuracy: 0.9668 (0.9572)
# Test: Epoch: [8]    [0/7]    eta: 0:00:00    loss: 0.1968 (0.1968)    accuracy: 0.9298 (0.9298)    time: 0.0164    data: 0.0156    max mem: 30
# Test: Epoch: [8]    [5/7]    eta: 0:00:00    loss: 0.1670 (0.1706)    accuracy: 0.9488 (0.9472)    time: 0.0158    data: 0.0152    max mem: 30
# Test: Epoch: [8] Total time: 0:00:00
# Averaged stats: loss: 0.1705 (0.1706)    accuracy: 0.9454 (0.9470)
# Epoch: [9]    [ 0/31]    eta: 0:00:00    lr: 0.009980    loss: 0.1451 (0.1451)    accuracy: 0.9646 (0.9646)    time: 0.0181    data: 0.0161    max mem: 30
# Epoch: [9]    [10/31]    eta: 0:00:00    lr: 0.009980    loss: 0.1386 (0.1442)    accuracy: 0.9704 (0.9652)    time: 0.0187    data: 0.0167    max mem: 30
# Epoch: [9]    [20/31]    eta: 0:00:00    lr: 0.009980    loss: 0.1326 (0.1426)    accuracy: 0.9736 (0.9658)    time: 0.0187    data: 0.0167    max mem: 30
# Epoch: [9]    [30/31]    eta: 0:00:00    lr: 0.009980    loss: 0.1307 (0.1403)    accuracy: 0.9659 (0.9664)    time: 0.0191    data: 0.0171    max mem: 30
# Epoch: [9] Total time: 0:00:00
# Averaged stats: lr: 0.009980    loss: 0.1307 (0.1403)    accuracy: 0.9659 (0.9664)
# Test: Epoch: [9]    [0/7]    eta: 0:00:00    loss: 0.1797 (0.1797)    accuracy: 0.9357 (0.9357)    time: 0.0173    data: 0.0168    max mem: 30
# Test: Epoch: [9]    [5/7]    eta: 0:00:00    loss: 0.1462 (0.1521)    accuracy: 0.9616 (0.9552)    time: 0.0172    data: 0.0166    max mem: 30
# Test: Epoch: [9] Total time: 0:00:00
# Averaged stats: loss: 0.1504 (0.1519)    accuracy: 0.9563 (0.9554)
# Epoch: [10]    [ 0/31]    eta: 0:00:01    lr: 0.009975    loss: 325.8332 (325.8332)    accuracy: 0.9596 (0.9596)    time: 0.0536    data: 0.0171    max mem: 30
# Epoch: [10]    [10/31]    eta: 0:00:01    lr: 0.009975    loss: 146.1176 (222.8540)    accuracy: 0.9143 (0.9323)    time: 0.0541    data: 0.0184    max mem: 30
# Epoch: [10]    [20/31]    eta: 0:00:00    lr: 0.009975    loss: 92.6233 (173.2547)    accuracy: 0.8599 (0.9089)    time: 0.0536    data: 0.0192    max mem: 30
# Epoch: [10]    [30/31]    eta: 0:00:00    lr: 0.009975    loss: 61.9820 (139.6608)    accuracy: 0.8368 (0.8894)    time: 0.0522    data: 0.0195    max mem: 30
# Epoch: [10] Total time: 0:00:01
# Averaged stats: lr: 0.009975    loss: 61.9820 (139.6608)    accuracy: 0.8368 (0.8894)
# Test: Epoch: [10]    [0/7]    eta: 0:00:00    loss: 0.3652 (0.3652)    accuracy: 0.8322 (0.8322)    time: 0.0197    data: 0.0191    max mem: 30
# Test: Epoch: [10]    [5/7]    eta: 0:00:00    loss: 0.3386 (0.3389)    accuracy: 0.8440 (0.8450)    time: 0.0162    data: 0.0157    max mem: 30
# Test: Epoch: [10] Total time: 0:00:00
# Averaged stats: loss: 0.3395 (0.3390)    accuracy: 0.8434 (0.8448)
# Save model from:  10
# Epoch: [11]    [ 0/31]    eta: 0:00:01    lr: 0.009970    loss: 66.0270 (66.0270)    accuracy: 0.8304 (0.8304)    time: 0.0513    data: 0.0162    max mem: 30
# Epoch: [11]    [10/31]    eta: 0:00:01    lr: 0.009970    loss: 50.9049 (56.5890)    accuracy: 0.8330 (0.8357)    time: 0.0500    data: 0.0185    max mem: 30
# Epoch: [11]    [20/31]    eta: 0:00:00    lr: 0.009970    loss: 44.9969 (52.3927)    accuracy: 0.8344 (0.8325)    time: 0.0499    data: 0.0187    max mem: 30
# Epoch: [11]    [30/31]    eta: 0:00:00    lr: 0.009970    loss: 39.9310 (49.4395)    accuracy: 0.8242 (0.8313)    time: 0.0548    data: 0.0187    max mem: 30
# Epoch: [11] Total time: 0:00:01
# Averaged stats: lr: 0.009970    loss: 39.9310 (49.4395)    accuracy: 0.8242 (0.8313)
# Test: Epoch: [11]    [0/7]    eta: 0:00:00    loss: 0.3848 (0.3848)    accuracy: 0.8244 (0.8244)    time: 0.0202    data: 0.0196    max mem: 30
# Test: Epoch: [11]    [5/7]    eta: 0:00:00    loss: 0.3565 (0.3569)    accuracy: 0.8362 (0.8369)    time: 0.0167    data: 0.0163    max mem: 30
# Test: Epoch: [11] Total time: 0:00:00
# Averaged stats: loss: 0.3568 (0.3569)    accuracy: 0.8357 (0.8367)
# Epoch: [12]    [ 0/31]    eta: 0:00:01    lr: 0.009965    loss: 42.3433 (42.3433)    accuracy: 0.8262 (0.8262)    time: 0.0554    data: 0.0162    max mem: 30
# Epoch: [12]    [10/31]    eta: 0:00:01    lr: 0.009965    loss: 38.2212 (39.4228)    accuracy: 0.8178 (0.8274)    time: 0.0495    data: 0.0178    max mem: 30
# Epoch: [12]    [20/31]    eta: 0:00:00    lr: 0.009965    loss: 34.0141 (37.7297)    accuracy: 0.8226 (0.8264)    time: 0.0492    data: 0.0184    max mem: 30
# Epoch: [12]    [30/31]    eta: 0:00:00    lr: 0.009965    loss: 32.0052 (36.2001)    accuracy: 0.8300 (0.8270)    time: 0.0497    data: 0.0191    max mem: 30
# Epoch: [12] Total time: 0:00:01
# Averaged stats: lr: 0.009965    loss: 32.0052 (36.2001)    accuracy: 0.8300 (0.8270)
# Test: Epoch: [12]    [0/7]    eta: 0:00:00    loss: 0.3832 (0.3832)    accuracy: 0.8252 (0.8252)    time: 0.0190    data: 0.0185    max mem: 30
# Test: Epoch: [12]    [5/7]    eta: 0:00:00    loss: 0.3556 (0.3561)    accuracy: 0.8368 (0.8374)    time: 0.0160    data: 0.0156    max mem: 30
# Test: Epoch: [12] Total time: 0:00:00
# Averaged stats: loss: 0.3559 (0.3561)    accuracy: 0.8359 (0.8372)
# Epoch: [13]    [ 0/31]    eta: 0:00:01    lr: 0.009958    loss: 30.5239 (30.5239)    accuracy: 0.8266 (0.8266)    time: 0.0502    data: 0.0159    max mem: 30
# Epoch: [13]    [10/31]    eta: 0:00:01    lr: 0.009958    loss: 30.8590 (31.0316)    accuracy: 0.8321 (0.8274)    time: 0.0495    data: 0.0181    max mem: 30
# Epoch: [13]    [20/31]    eta: 0:00:00    lr: 0.009958    loss: 29.9256 (30.9129)    accuracy: 0.8254 (0.8269)    time: 0.0491    data: 0.0182    max mem: 30
# Epoch: [13]    [30/31]    eta: 0:00:00    lr: 0.009958    loss: 28.4295 (30.1724)    accuracy: 0.8285 (0.8271)    time: 0.0483    data: 0.0177    max mem: 30
# Epoch: [13] Total time: 0:00:01
# Averaged stats: lr: 0.009958    loss: 28.4295 (30.1724)    accuracy: 0.8285 (0.8271)
# Test: Epoch: [13]    [0/7]    eta: 0:00:00    loss: 0.3836 (0.3836)    accuracy: 0.8244 (0.8244)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [13]    [5/7]    eta: 0:00:00    loss: 0.3557 (0.3563)    accuracy: 0.8363 (0.8368)    time: 0.0155    data: 0.0151    max mem: 30
# Test: Epoch: [13] Total time: 0:00:00
# Averaged stats: loss: 0.3559 (0.3562)    accuracy: 0.8358 (0.8367)
# Epoch: [14]    [ 0/31]    eta: 0:00:01    lr: 0.009952    loss: 27.9532 (27.9532)    accuracy: 0.8215 (0.8215)    time: 0.0544    data: 0.0160    max mem: 30
# Epoch: [14]    [10/31]    eta: 0:00:01    lr: 0.009952    loss: 28.0291 (27.7824)    accuracy: 0.8246 (0.8278)    time: 0.0487    data: 0.0171    max mem: 30
# Epoch: [14]    [20/31]    eta: 0:00:00    lr: 0.009952    loss: 26.3275 (27.3146)    accuracy: 0.8276 (0.8268)    time: 0.0495    data: 0.0185    max mem: 30
# Epoch: [14]    [30/31]    eta: 0:00:00    lr: 0.009952    loss: 26.7827 (27.1082)    accuracy: 0.8315 (0.8270)    time: 0.0512    data: 0.0197    max mem: 30
# Epoch: [14] Total time: 0:00:01
# Averaged stats: lr: 0.009952    loss: 26.7827 (27.1082)    accuracy: 0.8315 (0.8270)
# Test: Epoch: [14]    [0/7]    eta: 0:00:00    loss: 0.3834 (0.3834)    accuracy: 0.8247 (0.8247)    time: 0.0186    data: 0.0181    max mem: 30
# Test: Epoch: [14]    [5/7]    eta: 0:00:00    loss: 0.3553 (0.3559)    accuracy: 0.8364 (0.8372)    time: 0.0160    data: 0.0155    max mem: 30
# Test: Epoch: [14] Total time: 0:00:00
# Averaged stats: loss: 0.3554 (0.3558)    accuracy: 0.8360 (0.8370)
# Epoch: [15]    [ 0/31]    eta: 0:00:01    lr: 0.009945    loss: 26.1837 (26.1837)    accuracy: 0.8301 (0.8301)    time: 0.0506    data: 0.0160    max mem: 30
# Epoch: [15]    [10/31]    eta: 0:00:01    lr: 0.009945    loss: 25.3383 (25.9929)    accuracy: 0.8257 (0.8259)    time: 0.0490    data: 0.0186    max mem: 30
# Epoch: [15]    [20/31]    eta: 0:00:00    lr: 0.009945    loss: 25.1748 (25.6389)    accuracy: 0.8232 (0.8267)    time: 0.0492    data: 0.0191    max mem: 30
# Epoch: [15]    [30/31]    eta: 0:00:00    lr: 0.009945    loss: 24.5445 (25.2671)    accuracy: 0.8310 (0.8273)    time: 0.0505    data: 0.0189    max mem: 30
# Epoch: [15] Total time: 0:00:01
# Averaged stats: lr: 0.009945    loss: 24.5445 (25.2671)    accuracy: 0.8310 (0.8273)
# Test: Epoch: [15]    [0/7]    eta: 0:00:00    loss: 0.3818 (0.3818)    accuracy: 0.8254 (0.8254)    time: 0.0183    data: 0.0177    max mem: 30
# Test: Epoch: [15]    [5/7]    eta: 0:00:00    loss: 0.3545 (0.3548)    accuracy: 0.8372 (0.8379)    time: 0.0158    data: 0.0154    max mem: 30
# Test: Epoch: [15] Total time: 0:00:00
# Averaged stats: loss: 0.3545 (0.3548)    accuracy: 0.8369 (0.8378)
# Epoch: [16]    [ 0/31]    eta: 0:00:01    lr: 0.009937    loss: 23.7933 (23.7933)    accuracy: 0.8305 (0.8305)    time: 0.0514    data: 0.0161    max mem: 30
# Epoch: [16]    [10/31]    eta: 0:00:01    lr: 0.009937    loss: 23.3840 (23.9274)    accuracy: 0.8242 (0.8260)    time: 0.0497    data: 0.0187    max mem: 30
# Epoch: [16]    [20/31]    eta: 0:00:00    lr: 0.009937    loss: 24.5230 (24.0140)    accuracy: 0.8367 (0.8270)    time: 0.0495    data: 0.0180    max mem: 30
# Epoch: [16]    [30/31]    eta: 0:00:00    lr: 0.009937    loss: 22.7900 (23.7904)    accuracy: 0.8280 (0.8272)    time: 0.0497    data: 0.0181    max mem: 30
# Epoch: [16] Total time: 0:00:01
# Averaged stats: lr: 0.009937    loss: 22.7900 (23.7904)    accuracy: 0.8280 (0.8272)
# Test: Epoch: [16]    [0/7]    eta: 0:00:00    loss: 0.3816 (0.3816)    accuracy: 0.8255 (0.8255)    time: 0.0188    data: 0.0183    max mem: 30
# Test: Epoch: [16]    [5/7]    eta: 0:00:00    loss: 0.3543 (0.3546)    accuracy: 0.8376 (0.8382)    time: 0.0160    data: 0.0156    max mem: 30
# Test: Epoch: [16] Total time: 0:00:00
# Averaged stats: loss: 0.3544 (0.3546)    accuracy: 0.8373 (0.8380)
# Epoch: [17]    [ 0/31]    eta: 0:00:01    lr: 0.009929    loss: 23.7265 (23.7265)    accuracy: 0.8301 (0.8301)    time: 0.0453    data: 0.0160    max mem: 30
# Epoch: [17]    [10/31]    eta: 0:00:01    lr: 0.009929    loss: 22.5046 (23.1295)    accuracy: 0.8283 (0.8293)    time: 0.0508    data: 0.0197    max mem: 30
# Epoch: [17]    [20/31]    eta: 0:00:00    lr: 0.009929    loss: 22.2146 (22.8646)    accuracy: 0.8256 (0.8273)    time: 0.0508    data: 0.0194    max mem: 30
# Epoch: [17]    [30/31]    eta: 0:00:00    lr: 0.009929    loss: 22.4488 (22.6812)    accuracy: 0.8226 (0.8273)    time: 0.0498    data: 0.0187    max mem: 30
# Epoch: [17] Total time: 0:00:01
# Averaged stats: lr: 0.009929    loss: 22.4488 (22.6812)    accuracy: 0.8226 (0.8273)
# Test: Epoch: [17]    [0/7]    eta: 0:00:00    loss: 0.3820 (0.3820)    accuracy: 0.8251 (0.8251)    time: 0.0196    data: 0.0192    max mem: 30
# Test: Epoch: [17]    [5/7]    eta: 0:00:00    loss: 0.3543 (0.3548)    accuracy: 0.8373 (0.8378)    time: 0.0162    data: 0.0157    max mem: 30
# Test: Epoch: [17] Total time: 0:00:00
# Averaged stats: loss: 0.3544 (0.3547)    accuracy: 0.8368 (0.8377)
# Epoch: [18]    [ 0/31]    eta: 0:00:01    lr: 0.009920    loss: 23.0869 (23.0869)    accuracy: 0.8243 (0.8243)    time: 0.0511    data: 0.0162    max mem: 30
# Epoch: [18]    [10/31]    eta: 0:00:01    lr: 0.009920    loss: 21.6991 (22.5348)    accuracy: 0.8313 (0.8269)    time: 0.0503    data: 0.0190    max mem: 30
# Epoch: [18]    [20/31]    eta: 0:00:00    lr: 0.009920    loss: 20.7981 (22.0603)    accuracy: 0.8291 (0.8267)    time: 0.0502    data: 0.0193    max mem: 30
# Epoch: [18]    [30/31]    eta: 0:00:00    lr: 0.009920    loss: 22.1580 (21.9094)    accuracy: 0.8242 (0.8272)    time: 0.0495    data: 0.0186    max mem: 30
# Epoch: [18] Total time: 0:00:01
# Averaged stats: lr: 0.009920    loss: 22.1580 (21.9094)    accuracy: 0.8242 (0.8272)
# Test: Epoch: [18]    [0/7]    eta: 0:00:00    loss: 0.3829 (0.3829)    accuracy: 0.8250 (0.8250)    time: 0.0266    data: 0.0259    max mem: 30
# Test: Epoch: [18]    [5/7]    eta: 0:00:00    loss: 0.3550 (0.3555)    accuracy: 0.8371 (0.8377)    time: 0.0173    data: 0.0168    max mem: 30
# Test: Epoch: [18] Total time: 0:00:00
# Averaged stats: loss: 0.3553 (0.3555)    accuracy: 0.8366 (0.8376)
# Epoch: [19]    [ 0/31]    eta: 0:00:01    lr: 0.009911    loss: 20.7717 (20.7717)    accuracy: 0.8314 (0.8314)    time: 0.0459    data: 0.0161    max mem: 30
# Epoch: [19]    [10/31]    eta: 0:00:01    lr: 0.009911    loss: 21.7014 (21.1971)    accuracy: 0.8258 (0.8292)    time: 0.0509    data: 0.0192    max mem: 30
# Epoch: [19]    [20/31]    eta: 0:00:00    lr: 0.009911    loss: 21.1269 (21.2011)    accuracy: 0.8237 (0.8271)    time: 0.0564    data: 0.0192    max mem: 30
# Epoch: [19]    [30/31]    eta: 0:00:00    lr: 0.009911    loss: 20.3327 (21.1389)    accuracy: 0.8279 (0.8271)    time: 0.0559    data: 0.0191    max mem: 30
# Epoch: [19] Total time: 0:00:01
# Averaged stats: lr: 0.009911    loss: 20.3327 (21.1389)    accuracy: 0.8279 (0.8271)
# Test: Epoch: [19]    [0/7]    eta: 0:00:00    loss: 0.3829 (0.3829)    accuracy: 0.8251 (0.8251)    time: 0.0197    data: 0.0191    max mem: 30
# Test: Epoch: [19]    [5/7]    eta: 0:00:00    loss: 0.3549 (0.3555)    accuracy: 0.8371 (0.8377)    time: 0.0162    data: 0.0157    max mem: 30
# Test: Epoch: [19] Total time: 0:00:00
# Averaged stats: loss: 0.3552 (0.3554)    accuracy: 0.8366 (0.8376)
# Epoch: [20]    [ 0/31]    eta: 0:00:01    lr: 0.009902    loss: 20.8378 (20.8378)    accuracy: 0.8290 (0.8290)    time: 0.0492    data: 0.0161    max mem: 30
# Epoch: [20]    [10/31]    eta: 0:00:01    lr: 0.009902    loss: 21.1203 (20.8156)    accuracy: 0.8246 (0.8258)    time: 0.0508    data: 0.0188    max mem: 30
# Epoch: [20]    [20/31]    eta: 0:00:00    lr: 0.009902    loss: 20.1759 (20.7616)    accuracy: 0.8317 (0.8279)    time: 0.0511    data: 0.0188    max mem: 30
# Epoch: [20]    [30/31]    eta: 0:00:00    lr: 0.009902    loss: 19.7070 (20.6030)    accuracy: 0.8210 (0.8270)    time: 0.0512    data: 0.0191    max mem: 30
# Epoch: [20] Total time: 0:00:01
# Averaged stats: lr: 0.009902    loss: 19.7070 (20.6030)    accuracy: 0.8210 (0.8270)
# Test: Epoch: [20]    [0/7]    eta: 0:00:00    loss: 0.3827 (0.3827)    accuracy: 0.8249 (0.8249)    time: 0.0159    data: 0.0154    max mem: 30
# Test: Epoch: [20]    [5/7]    eta: 0:00:00    loss: 0.3550 (0.3554)    accuracy: 0.8372 (0.8378)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [20] Total time: 0:00:00
# Averaged stats: loss: 0.3553 (0.3554)    accuracy: 0.8364 (0.8376)
# Epoch: [21]    [ 0/31]    eta: 0:00:01    lr: 0.009892    loss: 20.6479 (20.6479)    accuracy: 0.8304 (0.8304)    time: 0.0468    data: 0.0164    max mem: 30
# Epoch: [21]    [10/31]    eta: 0:00:01    lr: 0.009892    loss: 20.0901 (20.7347)    accuracy: 0.8211 (0.8265)    time: 0.0491    data: 0.0175    max mem: 30
# Epoch: [21]    [20/31]    eta: 0:00:00    lr: 0.009892    loss: 20.3914 (20.4426)    accuracy: 0.8236 (0.8273)    time: 0.0509    data: 0.0186    max mem: 30
# Epoch: [21]    [30/31]    eta: 0:00:00    lr: 0.009892    loss: 19.8419 (20.3052)    accuracy: 0.8270 (0.8272)    time: 0.0523    data: 0.0190    max mem: 30
# Epoch: [21] Total time: 0:00:01
# Averaged stats: lr: 0.009892    loss: 19.8419 (20.3052)    accuracy: 0.8270 (0.8272)
# Test: Epoch: [21]    [0/7]    eta: 0:00:00    loss: 0.3819 (0.3819)    accuracy: 0.8259 (0.8259)    time: 0.0159    data: 0.0153    max mem: 30
# Test: Epoch: [21]    [5/7]    eta: 0:00:00    loss: 0.3542 (0.3547)    accuracy: 0.8376 (0.8382)    time: 0.0156    data: 0.0151    max mem: 30
# Test: Epoch: [21] Total time: 0:00:00
# Averaged stats: loss: 0.3544 (0.3547)    accuracy: 0.8367 (0.8380)
# Epoch: [22]    [ 0/31]    eta: 0:00:01    lr: 0.009881    loss: 19.9687 (19.9687)    accuracy: 0.8311 (0.8311)    time: 0.0507    data: 0.0162    max mem: 30
# Epoch: [22]    [10/31]    eta: 0:00:01    lr: 0.009881    loss: 20.0730 (19.9136)    accuracy: 0.8275 (0.8258)    time: 0.0517    data: 0.0182    max mem: 30
# Epoch: [22]    [20/31]    eta: 0:00:00    lr: 0.009881    loss: 20.3591 (19.9454)    accuracy: 0.8264 (0.8269)    time: 0.0512    data: 0.0188    max mem: 30
# Epoch: [22]    [30/31]    eta: 0:00:00    lr: 0.009881    loss: 19.4372 (19.9105)    accuracy: 0.8235 (0.8272)    time: 0.0500    data: 0.0185    max mem: 30
# Epoch: [22] Total time: 0:00:01
# Averaged stats: lr: 0.009881    loss: 19.4372 (19.9105)    accuracy: 0.8235 (0.8272)
# Test: Epoch: [22]    [0/7]    eta: 0:00:00    loss: 0.3824 (0.3824)    accuracy: 0.8251 (0.8251)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [22]    [5/7]    eta: 0:00:00    loss: 0.3548 (0.3553)    accuracy: 0.8370 (0.8375)    time: 0.0155    data: 0.0150    max mem: 30
# Test: Epoch: [22] Total time: 0:00:00
# Averaged stats: loss: 0.3550 (0.3552)    accuracy: 0.8361 (0.8373)
# Epoch: [23]    [ 0/31]    eta: 0:00:01    lr: 0.009870    loss: 18.7607 (18.7607)    accuracy: 0.8245 (0.8245)    time: 0.0459    data: 0.0161    max mem: 30
# Epoch: [23]    [10/31]    eta: 0:00:01    lr: 0.009870    loss: 19.7396 (19.4858)    accuracy: 0.8291 (0.8261)    time: 0.0507    data: 0.0193    max mem: 30
# Epoch: [23]    [20/31]    eta: 0:00:00    lr: 0.009870    loss: 19.1978 (19.4794)    accuracy: 0.8316 (0.8267)    time: 0.0513    data: 0.0196    max mem: 30
# Epoch: [23]    [30/31]    eta: 0:00:00    lr: 0.009870    loss: 19.8633 (19.4856)    accuracy: 0.8276 (0.8270)    time: 0.0509    data: 0.0189    max mem: 30
# Epoch: [23] Total time: 0:00:01
# Averaged stats: lr: 0.009870    loss: 19.8633 (19.4856)    accuracy: 0.8276 (0.8270)
# Test: Epoch: [23]    [0/7]    eta: 0:00:00    loss: 0.3822 (0.3822)    accuracy: 0.8249 (0.8249)    time: 0.0165    data: 0.0160    max mem: 30
# Test: Epoch: [23]    [5/7]    eta: 0:00:00    loss: 0.3550 (0.3554)    accuracy: 0.8366 (0.8374)    time: 0.0163    data: 0.0158    max mem: 30
# Test: Epoch: [23] Total time: 0:00:00
# Averaged stats: loss: 0.3551 (0.3553)    accuracy: 0.8361 (0.8372)
# Epoch: [24]    [ 0/31]    eta: 0:00:01    lr: 0.009859    loss: 19.6418 (19.6418)    accuracy: 0.8302 (0.8302)    time: 0.0522    data: 0.0166    max mem: 30
# Epoch: [24]    [10/31]    eta: 0:00:01    lr: 0.009859    loss: 19.2785 (19.4196)    accuracy: 0.8263 (0.8266)    time: 0.0502    data: 0.0179    max mem: 30
# Epoch: [24]    [20/31]    eta: 0:00:00    lr: 0.009859    loss: 19.4093 (19.3551)    accuracy: 0.8263 (0.8277)    time: 0.0511    data: 0.0185    max mem: 30
# Epoch: [24]    [30/31]    eta: 0:00:00    lr: 0.009859    loss: 19.3021 (19.2730)    accuracy: 0.8243 (0.8273)    time: 0.0516    data: 0.0188    max mem: 30
# Epoch: [24] Total time: 0:00:01
# Averaged stats: lr: 0.009859    loss: 19.3021 (19.2730)    accuracy: 0.8243 (0.8273)
# Test: Epoch: [24]    [0/7]    eta: 0:00:00    loss: 0.3819 (0.3819)    accuracy: 0.8255 (0.8255)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [24]    [5/7]    eta: 0:00:00    loss: 0.3543 (0.3548)    accuracy: 0.8375 (0.8381)    time: 0.0155    data: 0.0150    max mem: 30
# Test: Epoch: [24] Total time: 0:00:00
# Averaged stats: loss: 0.3545 (0.3548)    accuracy: 0.8368 (0.8379)
# Epoch: [25]    [ 0/31]    eta: 0:00:01    lr: 0.009847    loss: 19.3541 (19.3541)    accuracy: 0.8287 (0.8287)    time: 0.0500    data: 0.0161    max mem: 30
# Epoch: [25]    [10/31]    eta: 0:00:01    lr: 0.009847    loss: 18.4231 (19.0946)    accuracy: 0.8332 (0.8287)    time: 0.0510    data: 0.0198    max mem: 30
# Epoch: [25]    [20/31]    eta: 0:00:00    lr: 0.009847    loss: 18.7194 (18.9143)    accuracy: 0.8250 (0.8272)    time: 0.0507    data: 0.0194    max mem: 30
# Epoch: [25]    [30/31]    eta: 0:00:00    lr: 0.009847    loss: 18.8092 (18.9530)    accuracy: 0.8258 (0.8272)    time: 0.0513    data: 0.0192    max mem: 30
# Epoch: [25] Total time: 0:00:01
# Averaged stats: lr: 0.009847    loss: 18.8092 (18.9530)    accuracy: 0.8258 (0.8272)
# Test: Epoch: [25]    [0/7]    eta: 0:00:00    loss: 0.3824 (0.3824)    accuracy: 0.8251 (0.8251)    time: 0.0184    data: 0.0178    max mem: 30
# Test: Epoch: [25]    [5/7]    eta: 0:00:00    loss: 0.3548 (0.3553)    accuracy: 0.8373 (0.8379)    time: 0.0159    data: 0.0154    max mem: 30
# Test: Epoch: [25] Total time: 0:00:00
# Averaged stats: loss: 0.3550 (0.3552)    accuracy: 0.8366 (0.8377)
# Epoch: [26]    [ 0/31]    eta: 0:00:01    lr: 0.009834    loss: 19.1634 (19.1634)    accuracy: 0.8330 (0.8330)    time: 0.0465    data: 0.0162    max mem: 30
# Epoch: [26]    [10/31]    eta: 0:00:01    lr: 0.009834    loss: 19.0111 (18.8640)    accuracy: 0.8323 (0.8281)    time: 0.0506    data: 0.0190    max mem: 30
# Epoch: [26]    [20/31]    eta: 0:00:00    lr: 0.009834    loss: 18.5719 (18.7443)    accuracy: 0.8233 (0.8271)    time: 0.0505    data: 0.0189    max mem: 30
# Epoch: [26]    [30/31]    eta: 0:00:00    lr: 0.009834    loss: 18.7750 (18.7014)    accuracy: 0.8325 (0.8272)    time: 0.0648    data: 0.0183    max mem: 30
# Epoch: [26] Total time: 0:00:01
# Averaged stats: lr: 0.009834    loss: 18.7750 (18.7014)    accuracy: 0.8325 (0.8272)
# Test: Epoch: [26]    [0/7]    eta: 0:00:00    loss: 0.3820 (0.3820)    accuracy: 0.8256 (0.8256)    time: 0.0168    data: 0.0163    max mem: 30
# Test: Epoch: [26]    [5/7]    eta: 0:00:00    loss: 0.3546 (0.3550)    accuracy: 0.8378 (0.8381)    time: 0.0162    data: 0.0157    max mem: 30
# Test: Epoch: [26] Total time: 0:00:00
# Averaged stats: loss: 0.3546 (0.3549)    accuracy: 0.8372 (0.8380)
# Epoch: [27]    [ 0/31]    eta: 0:00:01    lr: 0.009821    loss: 18.3963 (18.3963)    accuracy: 0.8271 (0.8271)    time: 0.0506    data: 0.0161    max mem: 30
# Epoch: [27]    [10/31]    eta: 0:00:01    lr: 0.009821    loss: 18.7256 (18.5483)    accuracy: 0.8181 (0.8273)    time: 0.0537    data: 0.0200    max mem: 30
# Epoch: [27]    [20/31]    eta: 0:00:00    lr: 0.009821    loss: 17.7604 (18.5305)    accuracy: 0.8227 (0.8267)    time: 0.0524    data: 0.0194    max mem: 30
# Epoch: [27]    [30/31]    eta: 0:00:00    lr: 0.009821    loss: 18.5037 (18.4952)    accuracy: 0.8318 (0.8271)    time: 0.0506    data: 0.0187    max mem: 30
# Epoch: [27] Total time: 0:00:01
# Averaged stats: lr: 0.009821    loss: 18.5037 (18.4952)    accuracy: 0.8318 (0.8271)
# Test: Epoch: [27]    [0/7]    eta: 0:00:00    loss: 0.3828 (0.3828)    accuracy: 0.8250 (0.8250)    time: 0.0182    data: 0.0176    max mem: 30
# Test: Epoch: [27]    [5/7]    eta: 0:00:00    loss: 0.3549 (0.3555)    accuracy: 0.8369 (0.8377)    time: 0.0165    data: 0.0160    max mem: 30
# Test: Epoch: [27] Total time: 0:00:00
# Averaged stats: loss: 0.3551 (0.3554)    accuracy: 0.8368 (0.8376)
# Epoch: [28]    [ 0/31]    eta: 0:00:01    lr: 0.009808    loss: 18.8638 (18.8638)    accuracy: 0.8326 (0.8326)    time: 0.0463    data: 0.0164    max mem: 30
# Epoch: [28]    [10/31]    eta: 0:00:01    lr: 0.009808    loss: 18.5275 (18.5057)    accuracy: 0.8334 (0.8250)    time: 0.0510    data: 0.0194    max mem: 30
# Epoch: [28]    [20/31]    eta: 0:00:00    lr: 0.009808    loss: 18.4664 (18.3268)    accuracy: 0.8345 (0.8269)    time: 0.0516    data: 0.0200    max mem: 30
# Epoch: [28]    [30/31]    eta: 0:00:00    lr: 0.009808    loss: 18.0462 (18.2746)    accuracy: 0.8224 (0.8273)    time: 0.0517    data: 0.0202    max mem: 30
# Epoch: [28] Total time: 0:00:01
# Averaged stats: lr: 0.009808    loss: 18.0462 (18.2746)    accuracy: 0.8224 (0.8273)
# Test: Epoch: [28]    [0/7]    eta: 0:00:00    loss: 0.3820 (0.3820)    accuracy: 0.8254 (0.8254)    time: 0.0187    data: 0.0182    max mem: 30
# Test: Epoch: [28]    [5/7]    eta: 0:00:00    loss: 0.3547 (0.3551)    accuracy: 0.8372 (0.8379)    time: 0.0161    data: 0.0156    max mem: 30
# Test: Epoch: [28] Total time: 0:00:00
# Averaged stats: loss: 0.3547 (0.3551)    accuracy: 0.8369 (0.8378)
# Epoch: [29]    [ 0/31]    eta: 0:00:01    lr: 0.009794    loss: 18.3708 (18.3708)    accuracy: 0.8301 (0.8301)    time: 0.0455    data: 0.0161    max mem: 30
# Epoch: [29]    [10/31]    eta: 0:00:00    lr: 0.009794    loss: 17.9299 (18.2087)    accuracy: 0.8294 (0.8264)    time: 0.0471    data: 0.0168    max mem: 30
# Epoch: [29]    [20/31]    eta: 0:00:00    lr: 0.009794    loss: 18.1852 (18.2332)    accuracy: 0.8310 (0.8264)    time: 0.0485    data: 0.0180    max mem: 30
# Epoch: [29]    [30/31]    eta: 0:00:00    lr: 0.009794    loss: 17.2398 (18.1655)    accuracy: 0.8313 (0.8272)    time: 0.0499    data: 0.0190    max mem: 30
# Epoch: [29] Total time: 0:00:01
# Averaged stats: lr: 0.009794    loss: 17.2398 (18.1655)    accuracy: 0.8313 (0.8272)
# Test: Epoch: [29]    [0/7]    eta: 0:00:00    loss: 0.3823 (0.3823)    accuracy: 0.8252 (0.8252)    time: 0.0182    data: 0.0177    max mem: 30
# Test: Epoch: [29]    [5/7]    eta: 0:00:00    loss: 0.3546 (0.3551)    accuracy: 0.8372 (0.8378)    time: 0.0160    data: 0.0155    max mem: 30
# Test: Epoch: [29] Total time: 0:00:00
# Averaged stats: loss: 0.3547 (0.3551)    accuracy: 0.8366 (0.8376)
# Epoch: [30]    [ 0/31]    eta: 0:00:01    lr: 0.009780    loss: 17.5906 (17.5906)    accuracy: 0.8286 (0.8286)    time: 0.0496    data: 0.0162    max mem: 30
# Epoch: [30]    [10/31]    eta: 0:00:01    lr: 0.009780    loss: 17.9991 (17.7451)    accuracy: 0.8296 (0.8264)    time: 0.0499    data: 0.0184    max mem: 30
# Epoch: [30]    [20/31]    eta: 0:00:00    lr: 0.009780    loss: 17.8964 (17.8298)    accuracy: 0.8261 (0.8261)    time: 0.0509    data: 0.0192    max mem: 30
# Epoch: [30]    [30/31]    eta: 0:00:00    lr: 0.009780    loss: 18.1457 (17.8738)    accuracy: 0.8269 (0.8272)    time: 0.0510    data: 0.0198    max mem: 30
# Epoch: [30] Total time: 0:00:01
# Averaged stats: lr: 0.009780    loss: 18.1457 (17.8738)    accuracy: 0.8269 (0.8272)
# Test: Epoch: [30]    [0/7]    eta: 0:00:00    loss: 0.3824 (0.3824)    accuracy: 0.8249 (0.8249)    time: 0.0197    data: 0.0192    max mem: 30
# Test: Epoch: [30]    [5/7]    eta: 0:00:00    loss: 0.3547 (0.3553)    accuracy: 0.8367 (0.8375)    time: 0.0163    data: 0.0159    max mem: 30
# Test: Epoch: [30] Total time: 0:00:00
# Averaged stats: loss: 0.3551 (0.3552)    accuracy: 0.8362 (0.8373)
# Epoch: [31]    [ 0/31]    eta: 0:00:01    lr: 0.009765    loss: 17.6013 (17.6013)    accuracy: 0.8290 (0.8290)    time: 0.0468    data: 0.0169    max mem: 30
# Epoch: [31]    [10/31]    eta: 0:00:01    lr: 0.009765    loss: 17.6531 (17.7993)    accuracy: 0.8334 (0.8270)    time: 0.0512    data: 0.0195    max mem: 30
# Epoch: [31]    [20/31]    eta: 0:00:00    lr: 0.009765    loss: 17.4569 (17.7068)    accuracy: 0.8314 (0.8271)    time: 0.0516    data: 0.0195    max mem: 30
# Epoch: [31]    [30/31]    eta: 0:00:00    lr: 0.009765    loss: 17.4568 (17.6796)    accuracy: 0.8315 (0.8271)    time: 0.0499    data: 0.0178    max mem: 30
# Epoch: [31] Total time: 0:00:01
# Averaged stats: lr: 0.009765    loss: 17.4568 (17.6796)    accuracy: 0.8315 (0.8271)
# Test: Epoch: [31]    [0/7]    eta: 0:00:00    loss: 0.3819 (0.3819)    accuracy: 0.8252 (0.8252)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [31]    [5/7]    eta: 0:00:00    loss: 0.3545 (0.3549)    accuracy: 0.8370 (0.8379)    time: 0.0155    data: 0.0150    max mem: 30
# Test: Epoch: [31] Total time: 0:00:00
# Averaged stats: loss: 0.3546 (0.3549)    accuracy: 0.8367 (0.8377)
# Epoch: [32]    [ 0/31]    eta: 0:00:01    lr: 0.009750    loss: 17.7037 (17.7037)    accuracy: 0.8260 (0.8260)    time: 0.0453    data: 0.0161    max mem: 30
# Epoch: [32]    [10/31]    eta: 0:00:01    lr: 0.009750    loss: 17.4817 (17.5522)    accuracy: 0.8257 (0.8277)    time: 0.0489    data: 0.0186    max mem: 30
# Epoch: [32]    [20/31]    eta: 0:00:00    lr: 0.009750    loss: 17.8637 (17.5776)    accuracy: 0.8356 (0.8274)    time: 0.0491    data: 0.0189    max mem: 30
# Epoch: [32]    [30/31]    eta: 0:00:00    lr: 0.009750    loss: 17.9924 (17.6557)    accuracy: 0.8308 (0.8272)    time: 0.0496    data: 0.0195    max mem: 30
# Epoch: [32] Total time: 0:00:01
# Averaged stats: lr: 0.009750    loss: 17.9924 (17.6557)    accuracy: 0.8308 (0.8272)
# Test: Epoch: [32]    [0/7]    eta: 0:00:00    loss: 0.3830 (0.3830)    accuracy: 0.8252 (0.8252)    time: 0.0192    data: 0.0187    max mem: 30
# Test: Epoch: [32]    [5/7]    eta: 0:00:00    loss: 0.3554 (0.3558)    accuracy: 0.8373 (0.8379)    time: 0.0161    data: 0.0156    max mem: 30
# Test: Epoch: [32] Total time: 0:00:00
# Averaged stats: loss: 0.3556 (0.3558)    accuracy: 0.8367 (0.8377)
# Epoch: [33]    [ 0/31]    eta: 0:00:01    lr: 0.009734    loss: 18.1768 (18.1768)    accuracy: 0.8294 (0.8294)    time: 0.0504    data: 0.0162    max mem: 30
# Epoch: [33]    [10/31]    eta: 0:00:01    lr: 0.009734    loss: 16.9662 (17.4934)    accuracy: 0.8260 (0.8296)    time: 0.0488    data: 0.0189    max mem: 30
# Epoch: [33]    [20/31]    eta: 0:00:00    lr: 0.009734    loss: 17.3620 (17.4630)    accuracy: 0.8255 (0.8284)    time: 0.0494    data: 0.0190    max mem: 30
# Epoch: [33]    [30/31]    eta: 0:00:00    lr: 0.009734    loss: 17.3214 (17.4433)    accuracy: 0.8322 (0.8272)    time: 0.0498    data: 0.0186    max mem: 30
# Epoch: [33] Total time: 0:00:01
# Averaged stats: lr: 0.009734    loss: 17.3214 (17.4433)    accuracy: 0.8322 (0.8272)
# Test: Epoch: [33]    [0/7]    eta: 0:00:00    loss: 0.3821 (0.3821)    accuracy: 0.8253 (0.8253)    time: 0.0154    data: 0.0149    max mem: 30
# Test: Epoch: [33]    [5/7]    eta: 0:00:00    loss: 0.3546 (0.3550)    accuracy: 0.8371 (0.8379)    time: 0.0151    data: 0.0147    max mem: 30
# Test: Epoch: [33] Total time: 0:00:00
# Averaged stats: loss: 0.3548 (0.3550)    accuracy: 0.8370 (0.8378)
# Epoch: [34]    [ 0/31]    eta: 0:00:01    lr: 0.009718    loss: 17.2321 (17.2321)    accuracy: 0.8247 (0.8247)    time: 0.0493    data: 0.0163    max mem: 30
# Epoch: [34]    [10/31]    eta: 0:00:01    lr: 0.009718    loss: 17.5162 (17.4705)    accuracy: 0.8200 (0.8260)    time: 0.0591    data: 0.0165    max mem: 30
# Epoch: [34]    [20/31]    eta: 0:00:00    lr: 0.009718    loss: 17.1764 (17.4331)    accuracy: 0.8336 (0.8274)    time: 0.0531    data: 0.0164    max mem: 30
# Epoch: [34]    [30/31]    eta: 0:00:00    lr: 0.009718    loss: 17.5955 (17.4203)    accuracy: 0.8204 (0.8272)    time: 0.0477    data: 0.0175    max mem: 30
# Epoch: [34] Total time: 0:00:01
# Averaged stats: lr: 0.009718    loss: 17.5955 (17.4203)    accuracy: 0.8204 (0.8272)
# Test: Epoch: [34]    [0/7]    eta: 0:00:00    loss: 0.3830 (0.3830)    accuracy: 0.8247 (0.8247)    time: 0.0193    data: 0.0188    max mem: 30
# Test: Epoch: [34]    [5/7]    eta: 0:00:00    loss: 0.3552 (0.3556)    accuracy: 0.8368 (0.8375)    time: 0.0161    data: 0.0156    max mem: 30
# Test: Epoch: [34] Total time: 0:00:00
# Averaged stats: loss: 0.3554 (0.3556)    accuracy: 0.8365 (0.8374)
# Epoch: [35]    [ 0/31]    eta: 0:00:01    lr: 0.009701    loss: 17.0922 (17.0922)    accuracy: 0.8262 (0.8262)    time: 0.0531    data: 0.0161    max mem: 30
# Epoch: [35]    [10/31]    eta: 0:00:01    lr: 0.009701    loss: 17.4722 (17.2798)    accuracy: 0.8237 (0.8275)    time: 0.0482    data: 0.0170    max mem: 30
# Epoch: [35]    [20/31]    eta: 0:00:00    lr: 0.009701    loss: 16.9780 (17.1904)    accuracy: 0.8189 (0.8264)    time: 0.0487    data: 0.0183    max mem: 30
# Epoch: [35]    [30/31]    eta: 0:00:00    lr: 0.009701    loss: 17.5063 (17.2144)    accuracy: 0.8313 (0.8271)    time: 0.0500    data: 0.0198    max mem: 30
# Epoch: [35] Total time: 0:00:01
# Averaged stats: lr: 0.009701    loss: 17.5063 (17.2144)    accuracy: 0.8313 (0.8271)
# Test: Epoch: [35]    [0/7]    eta: 0:00:00    loss: 0.3823 (0.3823)    accuracy: 0.8253 (0.8253)    time: 0.0181    data: 0.0176    max mem: 30
# Test: Epoch: [35]    [5/7]    eta: 0:00:00    loss: 0.3547 (0.3552)    accuracy: 0.8370 (0.8378)    time: 0.0158    data: 0.0154    max mem: 30
# Test: Epoch: [35] Total time: 0:00:00
# Averaged stats: loss: 0.3548 (0.3551)    accuracy: 0.8368 (0.8377)
# Epoch: [36]    [ 0/31]    eta: 0:00:01    lr: 0.009684    loss: 17.7692 (17.7692)    accuracy: 0.8310 (0.8310)    time: 0.0502    data: 0.0160    max mem: 30
# Epoch: [36]    [10/31]    eta: 0:00:01    lr: 0.009684    loss: 17.0101 (17.2263)    accuracy: 0.8260 (0.8271)    time: 0.0490    data: 0.0180    max mem: 30
# Epoch: [36]    [20/31]    eta: 0:00:00    lr: 0.009684    loss: 17.3466 (17.2188)    accuracy: 0.8226 (0.8267)    time: 0.0483    data: 0.0178    max mem: 30
# Epoch: [36]    [30/31]    eta: 0:00:00    lr: 0.009684    loss: 16.7316 (17.1508)    accuracy: 0.8267 (0.8271)    time: 0.0475    data: 0.0173    max mem: 30
# Epoch: [36] Total time: 0:00:01
# Averaged stats: lr: 0.009684    loss: 16.7316 (17.1508)    accuracy: 0.8267 (0.8271)
# Test: Epoch: [36]    [0/7]    eta: 0:00:00    loss: 0.3822 (0.3822)    accuracy: 0.8247 (0.8247)    time: 0.0157    data: 0.0152    max mem: 30
# Test: Epoch: [36]    [5/7]    eta: 0:00:00    loss: 0.3548 (0.3553)    accuracy: 0.8369 (0.8375)    time: 0.0155    data: 0.0150    max mem: 30
# Test: Epoch: [36] Total time: 0:00:00
# Averaged stats: loss: 0.3550 (0.3552)    accuracy: 0.8361 (0.8373)
# Epoch: [37]    [ 0/31]    eta: 0:00:01    lr: 0.009666    loss: 16.8603 (16.8603)    accuracy: 0.8281 (0.8281)    time: 0.0459    data: 0.0160    max mem: 30
# Epoch: [37]    [10/31]    eta: 0:00:00    lr: 0.009666    loss: 17.0891 (16.9340)    accuracy: 0.8297 (0.8273)    time: 0.0466    data: 0.0161    max mem: 30

# %%
# visualize a input vector randomly from the dataset, plot the rx, tx and the output equalized rx from model
def visualize_output(model, data_loader, device):
    model.eval()

    random_index = random.randint(0, len(data_loader.dataset) - 1)
    tx_input, rx_input = data_loader.dataset[random_index]
    tx_input, rx_input = tx_input.to(device).unsqueeze(0), rx_input.to(device).unsqueeze(0)

    with torch.no_grad():
        with torch.amp.autocast('cuda'):
            equalized_output = model(rx_input).sigmoid().round()
            loss = F.mse_loss(equalized_output, tx_input)
    equalized_output = equalized_output.view(-1, 64, 8)
    tx_input = tx_input.view(-1, 64, 8)
    
    equalized_output = torch.sum(equalized_output * (2 ** torch.arange(7, -1, -1, device=device).float()), dim=-1).to(torch.uint8)
    tx_input = torch.sum(tx_input * (2 ** torch.arange(7, -1, -1, device=device).float()), dim=-1).to(torch.uint8)

    tx_input = tx_input.cpu().numpy()
    equalized_output = equalized_output.cpu().numpy()

    plt.figure(figsize=(10, 5))
    plt.plot(tx_input[0], label='tx')
    plt.plot(equalized_output[0], label='calibrated')
    plt.legend()
    plt.show()
    return

# the function to call this visual function
def test(snr):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    batch_size = 1
    
    val_data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_val.mat"
    val_dataset = channel_dataset_after_CNN(val_data_path, use_noise=True, is_train=False)
    val_sampler = data.SequentialSampler(val_dataset)
    val_loader = data.DataLoader(val_dataset, batch_size=batch_size, sampler=val_sampler, drop_last=True)
    
    model = Equalizer_HW_after_CNN().to(device)

    model_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model.pth"
    ckpt = torch.load(model_path)['model']
    # new_state_dict = {}
    # for k, v in ckpt.items():
    #     print(k)
    #     if "equalizer.0" in k:
    #         new_key = k.replace("equalizer.0", "equalizer.1")
    #     elif "equalizer.2" in k:
    #         new_key = k.replace("equalizer.2", "equalizer.3")
    #     new_state_dict[new_key] = v
        
    model.load_state_dict(ckpt)
    model.eval()

    visualize_output(model, val_loader, device)

    # saperate the last layer into 16 subblocks
    class Equalizer_HW_split(nn.Module):
        def __init__(self, input_size: int = 64, latent_size: int = 64):
            super(Equalizer_HW_split, self).__init__()
            self.equalizer = nn.Sequential(
                nn.Flatten(),
                nn.Linear(2 * 4 * 16, 128),
                nn.ReLU(),
                nn.Linear(128, input_size * 8 // 16)
            )
    
        def forward(self, rx_input):
            equalized_output = rx_input
            equalized_output = self.equalizer(equalized_output)
            return equalized_output
    
    model_HW_splits = [Equalizer_HW_split().to(device) for _ in range(16)]
    
    # Ensure the last layer exists and has the correct shape
    last_layer = list(model.equalizer.children())[-1]
    assert isinstance(last_layer, nn.Linear), "Expected the last layer to be Linear"
    assert last_layer.weight.data.shape[0] % 16 == 0, "Output size not divisible by 16"
    
    for i in range(16):
        # Assign only the last layer's weights and biases to each split model
        model_HW_splits[i].equalizer[-1].weight.data = last_layer.weight.data[i * 32: (i + 1) * 32, :].clone()
        model_HW_splits[i].equalizer[-1].bias.data = last_layer.bias.data[i * 32: (i + 1) * 32].clone()
    
        # If additional layers need loading, do so selectively
        for j, (split_layer, model_layer) in enumerate(zip(model_HW_splits[i].equalizer.children(), model.equalizer.children())):
            if j != len(model.equalizer) - 1:  # Skip the last layer
                split_layer.load_state_dict(model_layer.state_dict())


    # min, max of the model parameters
    min_params, max_params = [], []
    for p in model.parameters():
        min_params.append(p.min().item())
        max_params.append(p.max().item())
    min_params, max_params = np.min(min_params), np.max(max_params)
    print(f"Min of model parameters: {min_params}, Max of model parameters: {max_params}")
    # plot histogram of model parameters
    params = [p.detach().cpu().numpy().flatten() for p in model.parameters()]
    plt.hist(np.hstack(params), bins=100)
    plt.show()

    dummy_input = torch.randn(1, 1, 1, 128).to(device)
    torch.onnx.export(model, dummy_input,
                      "./channel_Rayleigh/" + str(snr) + "/PSK16/model_after_CNN.onnx",
                      export_params=True, opset_version=16, dynamic_axes={'input': {0: 'batch_size'}, 'sensor_out': {0: 'batch_size'}},
                      input_names=['input'], output_names=['sensor_out'])

    for i in range(16):
        path = "./channel_Rayleigh/" + str(snr) + "/PSK16/split_model_no_CNN/"
        if not os.path.exists(path):
            os.makedirs(path)
        torch.onnx.export(model_HW_splits[i], dummy_rx,
                          "./channel_Rayleigh/" + str(snr) + "/PSK16/split_model_no_CNN/best_model_HW_{}.onnx".format(i),
                          export_params=True, opset_version=16, dynamic_axes={'input': {0: 'batch_size'}, 'sensor_out': {0: 'batch_size'}},
                          input_names=['input'], output_names=['sensor_out'])
    return model

model = test(snr)
for p in model.parameters():
    print(p.mean(), p.std())
# Out:
# Min of model parameters: -3.4133095741271973, Max of model parameters: 3.701946496963501
# tensor(0.0056, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.5031, device='cuda:0', grad_fn=<StdBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1009, device='cuda:0', grad_fn=<StdBackward0>)
# tensor(-0.0022, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.3948, device='cuda:0', grad_fn=<StdBackward0>)
# tensor(-0.0061, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.1178, device='cuda:0', grad_fn=<StdBackward0>)

# %%
# visualize a input vector randomly from the dataset, plot the rx, tx and the output equalized rx from model
def visualize_output(model, data_loader, device, latent_vec):
    model.eval()

    tx_pilot, rx_pilot = data_loader.dataset.__get_pilot__()
    tx_pilot, rx_pilot = tx_pilot.to(device), rx_pilot.to(device)

    tx_pilot = tx_pilot.expand(data_loader.batch_size, -1, -1, -1)
    rx_pilot = rx_pilot.expand(data_loader.batch_size, -1, -1, -1)

    tx_pilot.requires_grad = False
    rx_pilot.requires_grad = False

    random_index = random.randint(0, len(data_loader.dataset) - 1)
    tx_input, rx_input = data_loader.dataset[random_index]
    tx_input, rx_input = tx_input.to(device).unsqueeze(0), rx_input.to(device).unsqueeze(0)
    if len(latent_vec.shape) != 4:
        latent_vec = latent_vec.view(-1, 1, 8, 8).expand(data_loader.batch_size, -1, -1, -1)
    rx_input = torch.cat((latent_vec, rx_input), dim=-1).contiguous()

    with torch.no_grad():
        with torch.amp.autocast('cuda'):
            equalized_output = model(rx_input)
            loss = F.mse_loss(equalized_output, tx_input)
            
            equalized_output = equalized_output.view(1, 64, -1).sigmoid().round()
            tx_input = tx_input.view(1, 64, -1)
            
            equalized_output = torch.sum(equalized_output * (2 ** torch.arange(7, -1, -1, device=device).float()), dim=-1).to(torch.uint8)
            tx_input = torch.sum(tx_input * (2 ** torch.arange(7, -1, -1, device=device).float()), dim=-1).to(torch.uint8)

    tx_input = tx_input.cpu().numpy()
    rx_input = (rx_input[:, :, :, 8:].contiguous().view(-1, 64).cpu().numpy() + 0.5) * 230 + 10

    equalized_output = equalized_output.cpu().numpy()

    plt.figure(figsize=(10, 5))
    plt.plot(tx_input[0], label='tx')
    plt.plot(rx_input[0], label='rx')
    plt.plot(equalized_output[0], label='calibrated')
    plt.legend()
    plt.show()
    return

# the function to call this visual function
def test(snr):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    batch_size = 1
    val_data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_val.mat"

    val_dataset = channel_dataset(val_data_path, use_noise=True, is_train=False)
    val_sampler = data.SequentialSampler(val_dataset)
    val_loader = data.DataLoader(val_dataset, batch_size=batch_size, sampler=val_sampler, drop_last=True)
    model = Equalizer().to(device)

    model_HW = Equalizer_HW().to(device)

    model_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model.pth"
    model.load_state_dict(torch.load(model_path)['model'])

    # take the tx_pilot and rx_pilot from the dataset
    val_data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_val.mat"
    val_dataset = channel_dataset(val_data_path, use_noise=True, is_train=False)
    tx_pilot, rx_pilot = val_dataset.__get_pilot__()
    tx_pilot, rx_pilot = tx_pilot.to(device), rx_pilot.to(device)

    with torch.no_grad():
        with torch.amp.autocast('cuda'):
            latent_vect = model.pilot_encoder(torch.cat((tx_pilot, rx_pilot), dim=1))

    model.eval()
    model_HW.eval()
    # model_HW.pilot_latent = nn.Parameter(model.pilot_encoder(torch.cat((tx_pilot, rx_pilot), dim=1)).clone().detach(), requires_grad=False)

    # copy the model's equalizer parameter to model_HW's equalizer
    model_HW.equalizer.load_state_dict(model.equalizer.state_dict())

    visualize_output(model_HW, val_loader, device, latent_vect)

    # min, max of the model parameters
    min_params, max_params = [], []
    for p in model.parameters():
        min_params.append(p.min().item())
        max_params.append(p.max().item())
    min_params, max_params = np.min(min_params), np.max(max_params)
    print(f"Min of model parameters: {min_params}, Max of model parameters: {max_params}")
    # plot histogram of model parameters
    params = [p.detach().cpu().numpy().flatten() for p in model.parameters()]
    plt.hist(np.hstack(params), bins=100)
    plt.show()

    return

test(snr)
# Out:
# Min of model parameters: -1.000726342201233, Max of model parameters: 1.0009753704071045

# %%
# export model to onnx
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Equalizer().to(device)

model_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model.pth"
model.load_state_dict(torch.load(model_path)['model'])


dummy_tx_pilot = torch.randn(1, 1, 64, 64).to(device)
dummy_rx_pilot = torch.randn(1, 1, 64, 64).to(device)
dummy_rx = torch.randn(1, 1, 8, 8).to(device)
dummy_input = (dummy_tx_pilot, dummy_rx_pilot, dummy_rx)
torch.onnx.export(model, dummy_input,
                  "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model.onnx",
                  export_params=True, opset_version=16, dynamic_axes={'input': {0: 'batch_size'}, 'sensor_out': {0: 'batch_size'}},
                  input_names=['input'], output_names=['sensor_out'])

# %%
# export model to onnx
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Equalizer().to(device)
model_HW = Equalizer_HW().to(device)

model_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model.pth"
model.load_state_dict(torch.load(model_path)['model'])

# take the tx_pilot and rx_pilot from the dataset
val_data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_val.mat"
val_dataset = channel_dataset(val_data_path, use_noise=True, is_train=False)
tx_pilot, rx_pilot = val_dataset.__get_pilot__()
tx_pilot, rx_pilot = tx_pilot.to(device), rx_pilot.to(device)

model.eval()
model_HW.eval()
# model_HW.pilot_latent = nn.Parameter(model.pilot_encoder(torch.cat((tx_pilot, rx_pilot), dim=1)).clone().detach(), requires_grad=False)
# copy the model's equalizer parameter to model_HW's equalizer
model_HW.equalizer.load_state_dict(model.equalizer.state_dict())

with torch.no_grad():
    with torch.amp.autocast('cuda'):
        latent_vect = model.pilot_encoder(torch.cat((tx_pilot, rx_pilot), dim=1))

rx_input = val_dataset.rx_data_noised / 255
latent_vect = latent_vect.reshape(1, 8, 8, 1).repeat(rx_input.shape[0], 1, 1, 1).cpu().detach().numpy() * 0.5 + 0.5

rx_input = np.concatenate((latent_vect, rx_input), axis=2)
print(rx_input.shape)
tx_input = [val_dataset.trans(tx).view(1, -1).cpu().detach().numpy() for tx in val_dataset.tx_data]
tx_input = np.concatenate(tx_input)

tx_input_label = val_dataset.tx_data_label.reshape(-1, 64, 8)

# save the new rx_input and tx_input into a new .npz file
np.savez("./channel_Rayleigh/" + str(snr) + "/PSK16/rx_input.npz", rx_input=rx_input, tx_input=tx_input, tx_input_label=tx_input_label)

# dummy_tx_pilot = torch.randn(1, 1, 64, 64).to(device)
# dummy_rx_pilot = torch.randn(1, 1, 64, 64).to(device)
dummy_rx = torch.randn(1, 1, 8, 16).to(device)
# dummy_input = (dummy_tx_pilot, dummy_rx_pilot, dummy_rx)
torch.onnx.export(model_HW, dummy_rx,
                  "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model_HW.onnx",
                  export_params=True, opset_version=16, dynamic_axes={'input': {0: 'batch_size'}, 'sensor_out': {0: 'batch_size'}},
                  input_names=['input'], output_names=['sensor_out'])
# Out:
# (1936, 8, 16, 1)

# %%
# saperate the last layer into 16 subblocks
model = Equalizer().to(device)
model_HW = Equalizer_HW()

class Equalizer_HW_split(nn.Module):
    def __init__(self, input_size: int = 64, latent_size: int = 64):
        super(Equalizer_HW_split, self).__init__()
        self.equalizer = nn.Sequential(
            nn.Conv2d(1, 4, 3, 1, 1),
            nn.AvgPool2d(2),
            nn.Conv2d(4, 8, 3, 1, 1),
            nn.AvgPool2d(2),
            nn.Conv2d(8, 16, 3, 1, 1),
            nn.Flatten(),
            nn.Linear(2 * 4 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, input_size * 8 // 16)
        )

    def forward(self, rx_input):
        equalized_output = rx_input
        equalized_output = self.equalizer(equalized_output)
        return equalized_output

model_HW_splits = [Equalizer_HW_split().to(device) for _ in range(16)]

model_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model.pth"
model.load_state_dict(torch.load(model_path)['model'])

print(model.equalizer[-1].weight.data.shape)
print(model.equalizer[-1].bias.data.shape)
# load each split models
# for i in range(16):
#     model_HW_splits[i].load_state_dict(model.equalizer.state_dict(), strict=False)
#     # load the last layer of model_HW_splits's equalizer from part of the model's equalizer's last layer
#     model_HW_splits[i].equalizer[-1].weight.data = model.equalizer[-1].weight.data[i * 32: (i + 1) * 32, :].clone()
#     model_HW_splits[i].equalizer[-1].bias.data = model.equalizer[-1].bias.data[i * 32: (i + 1) * 32].clone()

# Ensure the last layer exists and has the correct shape
last_layer = list(model.equalizer.children())[-1]
assert isinstance(last_layer, nn.Linear), "Expected the last layer to be Linear"
assert last_layer.weight.data.shape[0] % 16 == 0, "Output size not divisible by 16"

for i in range(16):
    # Assign only the last layer's weights and biases to each split model
    model_HW_splits[i].equalizer[-1].weight.data = last_layer.weight.data[i * 32: (i + 1) * 32, :].clone()
    model_HW_splits[i].equalizer[-1].bias.data = last_layer.bias.data[i * 32: (i + 1) * 32].clone()

    # If additional layers need loading, do so selectively
    for j, (split_layer, model_layer) in enumerate(zip(model_HW_splits[i].equalizer.children(), model.equalizer.children())):
        if j != len(model.equalizer) - 1:  # Skip the last layer
            split_layer.load_state_dict(model_layer.state_dict())
# Out:
# torch.Size([512, 128])
# torch.Size([512])

# %%
# test each output model with the original model
val_data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_val.mat"
val_dataset = channel_dataset(val_data_path, use_noise=True, is_train=False)
data_loader = data.DataLoader(val_dataset, batch_size=1, shuffle=True)

tx_pilot, rx_pilot = val_dataset.__get_pilot__()
tx_pilot, rx_pilot = tx_pilot.to(device), rx_pilot.to(device)
random_index = random.randint(0, len(data_loader.dataset) - 1)
tx_input, rx_input = data_loader.dataset[random_index]
tx_input, rx_input = tx_input.to(device).unsqueeze(0), rx_input.to(device).unsqueeze(0)

model.eval()

with torch.no_grad():
    with torch.amp.autocast('cuda'):
        latent_vec = model.pilot_encoder(torch.cat((tx_pilot, rx_pilot), dim=1))
        
if len(latent_vec.shape) != 4:
    latent_vec = latent_vec.view(-1, 1, 8, 8).expand(data_loader.batch_size, -1, -1, -1)
rx_input = torch.cat((latent_vec, rx_input), dim=-1).contiguous() 

with torch.no_grad():
    with torch.amp.autocast('cuda'):
        theory_out = model.equalizer(rx_input).view(1, 64, -1).sigmoid().round()

test_output = torch.zeros((1, 512), device=device)
for i in range(16):
    with torch.no_grad():
        with torch.amp.autocast('cuda'):
            model_HW_splits[i].eval()
            
            equalized_output = model_HW_splits[i](rx_input)
            test_output[:, i * 32: (i + 1) * 32] = equalized_output

# test_output = torch.cat(test_output, dim=-1)
test_output = test_output.sigmoid().round()
test_output = test_output.view(1, 64, -1)
tx_input = tx_input.view(1, 64, -1)

equalized_output = torch.sum(test_output * (2 ** torch.arange(7, -1, -1, device=device).float()), dim=-1).to(torch.uint8)
tx_input = torch.sum(tx_input * (2 ** torch.arange(7, -1, -1, device=device).float()), dim=-1).to(torch.uint8)
theory_out = torch.sum(theory_out * (2 ** torch.arange(7, -1, -1, device=device).float()), dim=-1).to(torch.uint8)

tx_input = tx_input.cpu().numpy()
equalized_output = equalized_output.cpu().numpy()
theory_out = theory_out.cpu().numpy()
rx_input = (rx_input[:, :, :, 8:].contiguous().view(-1, 64).cpu().numpy() + 0.5) * 230 + 10

# plot
plt.figure(figsize=(10, 5))
plt.plot(tx_input[0], label='tx')
plt.plot(rx_input[0], label='rx')
plt.plot(equalized_output[0], label='calibrated')
plt.plot(theory_out[0], label='calibrated theory')
plt.legend()
plt.show()

# %%
dummy_rx = torch.randn(1, 1, 8, 16).to(device)
# dummy_input = (dummy_tx_pilot, dummy_rx_pilot, dummy_rx)
for i in range(16):
    path = "./channel_Rayleigh/" + str(snr) + "/PSK16/split_model/"
    if not os.path.exists(path):
        os.makedirs(path)
    torch.onnx.export(model_HW_splits[i], dummy_rx,
                      "./channel_Rayleigh/" + str(snr) + "/PSK16/split_model/best_model_HW_{}.onnx".format(i),
                      export_params=True, opset_version=16, dynamic_axes={'input': {0: 'batch_size'}, 'sensor_out': {0: 'batch_size'}},
                      input_names=['input'], output_names=['sensor_out'])

# %%
# saperate the last layer into 16 subblocks
model = Equalizer().to(device)
model_HW = Equalizer_HW()

class Equalizer_HW_CNN(nn.Module):
    def __init__(self, input_size: int = 64, latent_size: int = 64):
        super(Equalizer_HW_CNN, self).__init__()
        self.equalizer = nn.Sequential(
            nn.Conv2d(1, 4, 3, 1, 1),
            nn.AvgPool2d(2),
            nn.Conv2d(4, 8, 3, 1, 1),
            nn.AvgPool2d(2),
            nn.Conv2d(8, 16, 3, 1, 1),
            nn.Flatten(),
        )

    def forward(self, rx_input):
        equalized_output = rx_input
        equalized_output = self.equalizer(equalized_output)
        return equalized_output

model_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model.pth"
model.load_state_dict(torch.load(model_path)['model'])

model_CNN = Equalizer_HW_CNN().to(device)

cnn_state_dict = {k: v for k, v in model.state_dict().items() if k.startswith("equalizer.0") or k.startswith("equalizer.1") or k.startswith("equalizer.2") or k.startswith("equalizer.3") or k.startswith("equalizer.4")}
model_CNN.load_state_dict(cnn_state_dict)

for n, p in model_CNN.named_parameters():
    if not torch.equal(p, cnn_state_dict[n]):
                print(f"Model and checkpoint parameters are not equal: model: {layer_name}")

# %%
# take the tx_pilot and rx_pilot from the dataset
train_data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_train.mat"
train_dataset = channel_dataset(train_data_path, use_noise=True, is_train=True)
tx_pilot, rx_pilot = train_dataset.__get_pilot__()
tx_pilot, rx_pilot = tx_pilot.to(device), rx_pilot.to(device)

with torch.no_grad():
    with torch.amp.autocast('cuda'):
        latent_vect = model.pilot_encoder(torch.cat((tx_pilot, rx_pilot), dim=1))

rx_input = train_dataset.rx_data_noised / 255
latent_vect = latent_vect.reshape(1, 8, 8, 1).repeat(rx_input.shape[0], 1, 1, 1).cpu().detach().numpy() * 0.5 + 0.5

rx_input = np.concatenate((latent_vect, rx_input), axis=2)
print(rx_input.shape)
tx_input = [val_dataset.trans(tx).view(1, -1).cpu().detach().numpy() for tx in val_dataset.tx_data]
tx_input = np.concatenate(tx_input)

tx_input_label = train_dataset.tx_data_label.reshape(-1, 64, 8)

# save the new rx_input and tx_input into a new .npz file
np.savez("./channel_Rayleigh/" + str(snr) + "/PSK16/rx_input_train.npz", rx_input=rx_input, tx_input=tx_input, tx_input_label=tx_input_label)

dummy_rx = torch.randn(1, 1, 8, 16).to(device)
# dummy_input = (dummy_tx_pilot, dummy_rx_pilot, dummy_rx)

path = "./channel_Rayleigh/" + str(snr) + "/PSK16/"
if not os.path.exists(path):
    os.makedirs(path)
torch.onnx.export(model_CNN, dummy_rx,
                  "./channel_Rayleigh/" + str(snr) + "/PSK16/best_model_CNN.onnx",
                  export_params=True, opset_version=16, dynamic_axes={'input': {0: 'batch_size'}, 'sensor_out': {0: 'batch_size'}},
                  input_names=['input'], output_names=['sensor_out'])
# Out:
# (7936, 8, 16, 1)

# %%
snr = 20
data_path = "./channel_Rayleigh/" + str(snr) + "/PSK16/shuffle/channel_equal_val.mat"
HW_data = np.load(data_path.replace("channel_equal_val.mat", "train_output.npy"))
print(HW_data.max())
# Out:
# 223
